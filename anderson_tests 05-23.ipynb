# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy.io as sio
from dataclasses import dataclass
from typing import List, Tuple
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
from tidy3d import web
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import AutomationModule as AM
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
a = 5/3

# %%
#Tight pulse to check beam 

lambdas = a/np.array([0.412,0.442]) #SAL
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample SAL Tight Beam 2"
postprocess_results = []
runtime = 5
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitorFieldOut","time_monitorFieldCenter"],
                                           freqs=600, 
                                           cut_condition=cutting, source="tight"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True)
            # #print(structure_1.estimate_cost())

            # sim_data, sim_data0, task_name_def = results
# Out:
# 01_Sample_600_res_L18.01_28ff_eps.h5
# Configured successfully.
# Simulation Parameters (wavelengths are expressed in um):
# Lx: 30 Ly: 30 Lz: 38.1
# lambda_range: 3.77 - 4.05 um
# lambdaw (pulse) 138.8888888888885
# lambda0 3.9032006245121
# Total runtime <= 2.3164173277649382 ps
# dl (Cube Size) = 34.91425152543692 nm
# Time Steps = 33637
# Grid Points = 656.7235109999999 million
# eps = 12.960000038146973
# 13:53:03 W. Europe Daylight Time Created task
#                                  '01_Sample_600_res_L18.01_28ff_eps_eps_12.96000
#                                  0038146973_size_30_runtime_5_lambdaRange_4.05-3
#                                  .77_incidence_z_0' with task_id
#                                  'fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=294256;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=926300;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\task]8;;\
#                                  ]8;id=926300;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\Id]8;;\]8;id=294256;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\=]8;;\]8;id=182325;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\fdve]8;;\]8;id=294256;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\-d64ae3b9-8416-498a-820e-ad6026aab0ab']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:53:06 W. Europe Daylight Time status = queued
# Output()
# 13:53:09 W. Europe Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 13:53:12 W. Europe Daylight Time You are running this simulation for FREE. Your
#                                  current plan allows up to 20 free
#                                  non-concurrent simulations per day (under
#                                  100.0M grid points and 50.0K time steps)
#                                  starting up solver
# 13:53:13 W. Europe Daylight Time running solver
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:53:26 W. Europe Daylight Time status = postprocess
# Output()
# 13:53:28 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  View simulation result at
#                                  ]8;id=64446;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=666393;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\task]8;;\
#                                  ]8;id=666393;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\Id]8;;\]8;id=64446;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\=]8;;\]8;id=861815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\fdve]8;;\]8;id=64446;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d64ae3b9-8416-498a-820e-ad6026aab0ab\-d64ae3b9-8416-498a-820e-ad6026aab0ab']8;;\.
# 13:53:29 W. Europe Daylight Time Created task
#                                  '01_Sample_600_res_L18.01_28ff_eps_eps_12.96000
#                                  0038146973_size_30_runtime_5_lambdaRange_4.05-3
#                                  .77_incidence_z' with task_id
#                                  'fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=408287;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=568026;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\task]8;;\
#                                  ]8;id=568026;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\Id]8;;\]8;id=408287;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\=]8;;\]8;id=546822;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\fdve]8;;\]8;id=408287;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\-c55c3d53-27c0-41fc-9d7e-36506565e7b9']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:54:32 W. Europe Daylight Time status = queued
# Output()
# 13:55:29 W. Europe Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 13:55:49 W. Europe Daylight Time You are running this simulation for FREE. Your
#                                  current plan allows up to 20 free
#                                  non-concurrent simulations per day (under
#                                  100.0M grid points and 50.0K time steps)
#                                  starting up solver
#                                  running solver
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# 14:00:58 W. Europe Daylight Time status = postprocess
# 14:02:28 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  View simulation result at
#                                  ]8;id=220330;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=467609;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\task]8;;\
#                                  ]8;id=467609;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\Id]8;;\]8;id=220330;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\=]8;;\]8;id=444003;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\fdve]8;;\]8;id=220330;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c55c3d53-27c0-41fc-9d7e-36506565e7b9\-c55c3d53-27c0-41fc-9d7e-36506565e7b9']8;;\.
# Folder 'RCP Sample SAL Tight Beam 2/z_incidence' created successfully.

# %%
lambdas = a/np.array([0.412,0.442]) #SAL
folder_path ="d:\phd stuff\structures\\18.01a"
project_name = "RCP Sample 1 Slices SAL"
postprocess_results = []
runtime = 30
min_steps_per_lambda = 15
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [0.1,0.3,0.5,0.7,0.9]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"], freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True)
            #print(structure_1.estimate_cost())

# %%
lambdas = a/np.array([0.47,0.49]) #Diffusion
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample Diffussion"
postprocess_results = []
runtime = 300
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"],
                                           freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=True,run_free=False, run=True)
            # #print(structure_1.estimate_cost())

            # sim_data, sim_data0, task_name_def = results

# %%
lambdas = a/np.array([0.412,0.442]) #SAL
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample SAL"
postprocess_results = []
runtime = 300
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"],
                                           freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=True,run_free=False, run=True)
            #print(structure_1.estimate_cost())

            sim_data, sim_data0, task_name_def = results

# %%
lambdas = a/np.array([0.35,0.56]) #Diffusion
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample All Gap Range"
postprocess_results = []
runtime = 700
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"],
                                           freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True)
            #print(structure_1.estimate_cost())

            #sim_data, sim_data0, task_name_def = results

# %%
# #Plot flux
#Retrieve the power flux through the monitor plane.
# transmission0 = sim_data0['flux1'].flux
# transmission = sim_data['flux1'].flux
# transmission_normalized = transmission / transmission0
# transmission_flux_right = sim_data['flux1'].flux
# transmission_flux_left = sim_data['flux2'].flux
# monitor_lambdas = a/((td.C_0/np.array(np.array(sim_data.simulation.monitors)[0].freqs)))
# fig = plt.figure()
# ax = fig.add_subplot(2, 1, 1)
# ax.scatter(monitor_lambdas, (transmission_flux_left/transmission0), label='Left Monitor',s=0.5)
# ax.scatter(monitor_lambdas, (transmission_flux_right/transmission0), label='Right Monitor',s=0.5)
# plt.xlabel(r'$a/\lambda$')
# plt.ylabel('T')
# plt.legend()
# ax.set_yscale("log")
# plt.grid()
# plt.show()

#     int_half = sim_data.get_intensity("time_monitorH")
#     int_end = sim_data.get_intensity("time_monitorFinal")
#     flux_f = sim_data["flux1"].flux
#     flux_t = sim_data["time_monitorT"].flux
#     def take_log(intensity):
#         return np.log10(intensity / np.max(intensity)+1e-2)
#     take_log(int_half).interp(z=0).squeeze().plot.pcolormesh()
#     plt.show()
#     take_log(int_end).interp(z=0).squeeze().plot.pcolormesh()
#     plt.show()
#     fig = plt.figure()
#     ax = plt.gca()
#     ax.scatter(flux_t['t'],flux_t)
#     plt.ylabel("Flux")
#     plt.xlabel("Time[ps]")
#     #plt.ylim(1e-17,1e-1)
#     ax.set_yscale("log")
