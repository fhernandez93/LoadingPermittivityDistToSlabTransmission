# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy.io as sio
from dataclasses import dataclass
from typing import List, Tuple
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
from tidy3d import web
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import AutomationModule as AM

# %%
tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
a = 5/3

# %%
#Tight pulse near from gap slices

lambdas = a/np.array([0.425,0.435]) #SAL
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample Tight Beam Near Gap Slices 1"
runtime = 5
min_steps_per_lambda = 25
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [0.15,0.3,0.5,0.7,0.9,1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True,
                                           monitors=["flux","time_monitorFieldOut","time_monitorFieldCenter"],
                                           freqs=600, 
                                           cut_condition=cutting, source="tight"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True,add_ref=False)

# %%
lambdas = a/np.array([0.425,0.435]) #SAL
folder_path ="d:\phd stuff\structures\\18.01a"
project_name = "RCP Sample 1 Slices SAL Time Transmission Near Gap"
postprocess_results = []
runtime = 11
min_steps_per_lambda = 15
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [0.1,0.15,0.3,0.5,0.7,0.9,1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"], freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True,add_ref=True)
            #print(structure_1.estimate_cost())

# %%
lambdas = a/np.array([0.35,0.56]) #SAL
folder_path ="d:\phd stuff\structures\\18.01a"
project_name = "RCP Sample 1 Slices SAL Gap Formation"
postprocess_results = []
runtime = 300
min_steps_per_lambda = 20
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [0.9,1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"], freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True,add_ref=True)
            #print(structure_1.estimate_cost())

# %%
#Tight pulse far from gap

lambdas = a/np.array([0.37,0.40]) #Far from Gap
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample SAL Tight Beam Far Gap 1"
runtime = 15
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True,
                                           monitors=["flux","time_monitorFieldOut","time_monitorFieldCenter"],
                                           freqs=600, 
                                           cut_condition=cutting, source="tight"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True,add_ref=False)
            # #print(structure_1.estimate_cost())

            # sim_data, sim_data0, task_name_def = results

# %%
#Slices far from gap

lambdas = a/np.array([0.37,0.40]) #Far from Gap
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample Far From gap (Diffusion)"
postprocess_results = []
runtime = 15
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True,
                                           monitors=["flux","time_monitorFieldOut","time_monitorFieldCenter"],
                                           freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True)
            # #print(structure_1.estimate_cost())

            # sim_data, sim_data0, task_name_def = results

# %%
#Tight pulse in SAL range

lambdas = a/np.array([0.412,0.442]) #SAL
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample SAL Tight Beam 3"
postprocess_results = []
runtime = 15
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True,
                                           monitors=["flux","time_monitorFieldOut","time_monitorFieldCenter"],
                                           freqs=600, 
                                           cut_condition=cutting, source="tight"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True)
            # #print(structure_1.estimate_cost())

            # sim_data, sim_data0, task_name_def = results

# %%
#Tight pulse in SAL range

lambdas = a/np.array([0.412,0.442]) #SAL
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample SAL Tight Beam 4 (10%)"
postprocess_results = []
runtime = 15
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True,
                                           monitors=["flux","time_monitorFieldOut","time_monitorFieldCenter"],
                                           freqs=600, 
                                           cut_condition=cutting, source="tight"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True)
            # #print(structure_1.estimate_cost())

            # sim_data, sim_data0, task_name_def = results

# %%
lambdas = a/np.array([0.412,0.442]) #SAL
folder_path ="d:\phd stuff\structures\\18.01a"
project_name = "RCP Sample 1 Slices SAL"
postprocess_results = []
runtime = 30
min_steps_per_lambda = 15
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [0.1,0.3,0.5,0.7,0.9]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"], freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True)
            #print(structure_1.estimate_cost())

# %%
lambdas = a/np.array([0.47,0.49]) #Diffusion GAP
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample Diffussion"
postprocess_results = []
runtime = 300
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"],
                                           freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=True,run_free=False, run=True)
            # #print(structure_1.estimate_cost())

            # sim_data, sim_data0, task_name_def = results

# %%
lambdas = a/np.array([0.412,0.442]) #SAL
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample SAL"
postprocess_results = []
runtime = 300
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"],
                                           freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=True,run_free=False, run=True)
            #print(structure_1.estimate_cost())

            sim_data, sim_data0, task_name_def = results

# %%
lambdas = a/np.array([0.35,0.56]) #All Range
folder_path =r"d:\phd stuff\structures\\18.01a"
project_name = r"RCP Sample All Gap Range"
postprocess_results = []
runtime = 700
min_steps_per_lambda = 30
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     for cutting in [1.0]:
        print(filename)
        if not (Path(filename).suffix==".h5"):
            continue 
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=lambdas,
                                            box_size=18.01*a,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
                                           scaling=1.0,shuoff_condtion=1e-12, verbose=True, 
                                           monitors=["flux","time_monitor"],
                                           freqs=600, 
                                           cut_condition=cutting, source="planewave"
                                           
                                           
                                           )
           
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, run=True)
            #print(structure_1.estimate_cost())

            #sim_data, sim_data0, task_name_def = results

# %%
# #Plot flux
#Retrieve the power flux through the monitor plane.
# transmission0 = sim_data0['flux1'].flux
# transmission = sim_data['flux1'].flux
# transmission_normalized = transmission / transmission0
# transmission_flux_right = sim_data['flux1'].flux
# transmission_flux_left = sim_data['flux2'].flux
# monitor_lambdas = a/((td.C_0/np.array(np.array(sim_data.simulation.monitors)[0].freqs)))
# fig = plt.figure()
# ax = fig.add_subplot(2, 1, 1)
# ax.scatter(monitor_lambdas, (transmission_flux_left/transmission0), label='Left Monitor',s=0.5)
# ax.scatter(monitor_lambdas, (transmission_flux_right/transmission0), label='Right Monitor',s=0.5)
# plt.xlabel(r'$a/\lambda$')
# plt.ylabel('T')
# plt.legend()
# ax.set_yscale("log")
# plt.grid()
# plt.show()

#     int_half = sim_data.get_intensity("time_monitorH")
#     int_end = sim_data.get_intensity("time_monitorFinal")
#     flux_f = sim_data["flux1"].flux
#     flux_t = sim_data["time_monitorT"].flux
#     def take_log(intensity):
#         return np.log10(intensity / np.max(intensity)+1e-2)
#     take_log(int_half).interp(z=0).squeeze().plot.pcolormesh()
#     plt.show()
#     take_log(int_end).interp(z=0).squeeze().plot.pcolormesh()
#     plt.show()
#     fig = plt.figure()
#     ax = plt.gca()
#     ax.scatter(flux_t['t'],flux_t)
#     plt.ylabel("Flux")
#     plt.xlabel("Time[ps]")
#     #plt.ylim(1e-17,1e-1)
#     ax.set_yscale("log")
