# %%
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import AutomationModule as AM

# %%
tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
# folder_path ="D:\phd stuff\\tidy3d\structures\\06_05_2024"
# project_name = "LSU Tight Beam"
# postprocess_results = []
# runtime = 500
# min_steps_per_lambda = 30
# for direction in ["z"]: 
#     for filename in os.listdir(folder_path):
#      for cutting in [1.0]:
#         print(filename)
#         if not (Path(filename).suffix==".h5"):
#             continue 
#         if os.path.isfile(os.path.join(folder_path, filename)):
#             file=os.path.join(folder_path, filename)
#             structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
#                                             ,direction=direction, lambda_range=[8.0,6.0],
#                                             box_size=14.3,runtime=runtime,min_steps_per_lambda=min_steps_per_lambda,
#                                            scaling=1,shuoff_condtion=1e-12, verbose=True,
#                                              #monitors=["flux","field_monitor","permittivity_monitor","field_time_domain","time_monitor"], 
#                                              monitors=["flux","time_monitor"], 
#                                            freqs=400, 
#                                            cut_condition=cutting, source="tight")
            
           
#             print(structure_1.__str__())
#             structure_1.plot_sim_layout()
#             #print(structure_1.estimate_cost())
#             results = structure_1.run_sim(folder_description=project_name,load=False,run_free=False, add_ref=True, run=False)

# %%
folder_path = "structures/test_stl_17_04_2024"
project_name = "LSU_STL_phi27_Absorption"
#index_dist = "https://refractiveindex.info/data_csv.php?datafile=database/data-nk/main/Si/Aspnes.yml" #0.21 - 0.83
#index_dist = "https://refractiveindex.info/data_csv.php?datafile=database/data-nk/main/Si/Schinke.yml" #0.25 - 1.45
index_dist = "https://web.archive.org/web/20230207133303/https://refractiveindex.info/data_csv.php?datafile=data/main/Si/Schinke.yml" #0.25–1.45 µm

runtime = 600
min_steps_per_lambda = 50
for direction in ["z"]: 
    for filename in os.listdir(folder_path):
     if not (Path(filename).suffix==".stl") or filename!="lsu_phi_27.stl":
            continue 
     print(filename)
     #for perm in [11.56,9.0,7.5,6.25,3.6]:
     for scale in [0.55,0.57,0.59,0.6,0.63,0.65,0.7]:
        print("scale:",scale)
        
        if os.path.isfile(os.path.join(folder_path, filename)):
            file=os.path.join(folder_path, filename)
            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                            ,direction=direction, lambda_range=[0.8,0.3],
                                            box_size=(14.3/10),runtime=runtime,min_steps_per_lambda=min_steps_per_lambda, permittivity=11.56, permittivity_dist= index_dist,
                                           scaling=scale,shuoff_condtion=1e-20, monitors=["flux"],verbose=True)
            
            
            print(structure_1.__str__())
            structure_1.plot_sim_layout()
            #print(structure_1.estimate_cost())
            
            results = structure_1.run_sim(folder_description=project_name,load=True,run_free=False)

            # sim_data, sim_data0, task_name_def = results
            # #Plot flux
            # #Retrieve the power flux through the monitor plane.
            # transmission0 = sim_data0['flux1'].flux
            # transmission = sim_data['flux1'].flux
            # transmission_normalized = transmission / transmission0
            # transmission_flux_right = sim_data['flux1'].flux
            # transmission_flux_left = sim_data['flux2'].flux
            # monitor_lambdas = td.C_0/np.array(np.array(sim_data.simulation.monitors)[0].freqs)
            # #plt.semilogy(monitor_lambdas, (transmission_flux_left/transmission0), label='Left Monitor')
            # plt.semilogy(monitor_lambdas, (transmission_flux_right/transmission0), label='Right Monitor')
            # plt.xlabel('$\lambda (\mu m)$')
            # plt.ylabel('T')
            # plt.legend()
            # plt.grid()
            # plt.title(f"{task_name_def}\n")
            # plt.show()
    ##
# Out:
# lsu_phi_27.stl
# scale: 0.55
# Configured successfully.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 12:34:51 W. Europe Daylight Time WARNING: Unable to fit with weighted RMS error
#                                  under 'tolerance_rms' of 0.02
# Simulation Parameters (wavelengths are expressed in um):
# Lx: 0.787 Ly: 0.787 Lz: 2.39
# lambda_range: 0.3 - 0.8 um
# lambdaw (pulse) 1.1999999999999997
# lambda0 0.4363636363636363
# Total runtime <= 2.4016614854266947 ps
# dl (Cube Size) = 1.7647058823529413 nm
# Time Steps = 698301
# Grid Points = 134.96815999999998 million
# eps = 11.56
# 12:34:53 W. Europe Daylight Time Created task
#                                  'lsu_phi_27_eps_11.56_size_0.787_runtime_600_la
#                                  mbdaRange_0.8-0.3_incidence_z_0' with task_id
#                                  'fdve-7e721198-8a12-4e67-8079-1950d2bbd79e' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=477179;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=348638;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\task]8;;\
#                                  ]8;id=348638;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\Id]8;;\]8;id=477179;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\=]8;;\]8;id=745623;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\fdve]8;;\]8;id=477179;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\-7e721198-8a12-4e67-8079-1950d2bbd79e']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 12:34:56 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# 12:35:02 W. Europe Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:35:04 W. Europe Daylight Time Maximum FlexCredit cost: 0.152. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
#                                  starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 12:36:23 W. Europe Daylight Time status = postprocess
# Output()
# 12:36:24 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  View simulation result at
#                                  ]8;id=32436;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=271551;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\task]8;;\
#                                  ]8;id=271551;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\Id]8;;\]8;id=32436;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\=]8;;\]8;id=522085;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\fdve]8;;\]8;id=32436;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7e721198-8a12-4e67-8079-1950d2bbd79e\-7e721198-8a12-4e67-8079-1950d2bbd79e']8;;\.
#                                  Created task
#                                  'lsu_phi_27_eps_11.56_size_0.787_runtime_600_la
#                                  mbdaRange_0.8-0.3_incidence_z' with task_id
#                                  'fdve-424010be-5d87-48c5-ab2a-f2abae827ae2' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=866667;https://tidy3d.simulation.cloud/workbench?taskId=fdve-424010be-5d87-48c5-ab2a-f2abae827ae2\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=416118;https://tidy3d.simulation.cloud/workbench?taskId=fdve-424010be-5d87-48c5-ab2a-f2abae827ae2\task]8;;\
#                                  ]8;id=416118;https://tidy3d.simulation.cloud/workbench?taskId=fdve-424010be-5d87-48c5-ab2a-f2abae827ae2\Id]8;;\]8;id=866667;https://tidy3d.simulation.cloud/workbench?taskId=fdve-424010be-5d87-48c5-ab2a-f2abae827ae2\=]8;;\]8;id=57073;https://tidy3d.simulation.cloud/workbench?taskId=fdve-424010be-5d87-48c5-ab2a-f2abae827ae2\fdve]8;;\]8;id=866667;https://tidy3d.simulation.cloud/workbench?taskId=fdve-424010be-5d87-48c5-ab2a-f2abae827ae2\-424010be-5d87-48c5-ab2a-f2abae827ae2']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 12:36:50 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# 12:37:06 W. Europe Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:37:35 W. Europe Daylight Time You are running this simulation for FREE. Your
#                                  current plan allows up to 20 free
#                                  non-concurrent simulations per day (under
#                                  100.0M grid points and 50.0K time steps)
#                                  starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 30
#      27         structure_1.plot_sim_layout()
#      28         #print(structure_1.estimate_cost())
# ---> 30         results = structure_1.run_sim(folder_description=project_name,load=True,run_free=False)
#      32         # sim_data, sim_data0, task_name_def = results
#      33         # #Plot flux
#      34         # #Retrieve the power flux through the monitor plane.
#    (...)
#      48         # plt.show()
#      49 ##
#
# File h:\phd stuff\tidy3d\AutomationModule\loadStructures.py:627, in loadAndRunStructure.run_sim(self, run_free, folder_description, max_grid_size, max_time_steps, load, run, add_ref)
#     625 if run:
#     626     web.start(task_id = id)
# --> 627     web.monitor(task_id=id,verbose=self.verbose)
#     629 #Store ids in an file
#     631 if run:
#
# File c:\Users\HernandF\AppData\Local\Programs\Python\Python312\Lib\site-packages\tidy3d\web\api\webapi.py:450, in monitor(task_id, verbose)
#     448     new_description = f"solver progress (field decay = {field_decay:.2e})"
#     449     progress.update(pbar_pd, completed=perc_done, description=new_description)
# --> 450     time.sleep(RUN_REFRESH_TIME)
#     452 perc_done, field_decay = get_run_info(task_id)
#     453 if perc_done is not None and perc_done < 100 and field_decay > 0:
#
# KeyboardInterrupt:
