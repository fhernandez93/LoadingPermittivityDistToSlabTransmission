# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy.io as sio
from dataclasses import dataclass
from typing import List, Tuple
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
from tidy3d import web
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from natsort import natsorted
import numpy as np
import matplotlib.animation as animation
import xarray as xr
import imageio
import matplotlib
import gc
import sys
import io

# Assuming /AutomationModule is in the root directory of your project
sys.path.append(os.path.abspath(rf'H:\phd stuff\tidy3d'))

from AutomationModule import * 

import AutomationModule as AM

tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
folder = rf"H:\phd stuff\tidy3d\data\10_04_2024 Beam Spreading Tight Bandwidth Periodic Conditions L=12"
       
data_field_intensities = np.zeros(shape=(12,1,20,358, 188, 1540),dtype=np.float16)

for i,item in enumerate(os.listdir(folder)):
    chi_path = os.path.join(folder, item)
    for j,item2 in enumerate(natsorted(os.listdir(chi_path))):
        if j == 0:
            chi_freq_folder=os.path.join(chi_path, item2)
            for k,item3 in enumerate(natsorted(os.listdir(chi_freq_folder))):
                file=os.path.join(chi_freq_folder, item3)
                old_stdout = sys.stdout
                sys.stdout = io.StringIO()
                try:
                    sim_result = (AM.loadFromFile(key = tidy3dAPI, file_path=file, save_path=rf"F:\2D SHU Chi Statistics",only_download=False,get_ref=False))
                finally:
                    # Reset sys.stdout back to the original state
                    sys.stdout = old_stdout
                data_field_intensities[i,j,k]=np.array(sim_result.sim_data.get_intensity("time_monitorFieldOut").values.squeeze(),dtype=np.float16)[:358,:188,:1540]

# %%
AM.create_hdf5_from_dict({
    "data_field_intensities": data_field_intensities,
    "chi":np.array([0.2,0.3,0.31,0.32,0.33,0.34,0.35,0.36,0.37,0.38,0.39,0.4,0]),
    "sample":np.arange(0,20,1),
    "x":sim_result.sim_data.get_intensity("freq_monitorFieldOut").x.values[:358],
    "y":sim_result.sim_data.get_intensity("freq_monitorFieldOut").y.values[:188],
    "t":sim_result.sim_data.get_intensity("freq_monitorFieldOut").t.values[:1540],
},rf"F:\2D SHU Chi Statistics\data\10_04_2024 Beam Spreading Tight Bandwidth Periodic Conditions L=12\intensities_0.h5")

# %%
folder = rf"H:\phd stuff\tidy3d\data\10_04_2024 Beam Spreading Tight Bandwidth Periodic Conditions L=12"
       
data_field_intensities = np.zeros(shape=(12,1,20,395, 208, 1710),dtype=np.float16)

for i,item in enumerate(os.listdir(folder)):
    chi_path = os.path.join(folder, item)
    for j,item2 in enumerate(natsorted(os.listdir(chi_path))):
        if j == 1:
            chi_freq_folder=os.path.join(chi_path, item2)
            for k,item3 in enumerate(natsorted(os.listdir(chi_freq_folder))):
                file=os.path.join(chi_freq_folder, item3)
                old_stdout = sys.stdout
                sys.stdout = io.StringIO()
                try:
                    sim_result = (AM.loadFromFile(key = tidy3dAPI, file_path=file, save_path=rf"F:\2D SHU Chi Statistics",only_download=False,get_ref=False))
                finally:
                    # Reset sys.stdout back to the original state
                    sys.stdout = old_stdout

                print(np.shape(sim_result.sim_data.get_intensity("time_monitorFieldOut").values.squeeze()))
                data_field_intensities[i,j,k]=np.array(sim_result.sim_data.get_intensity("time_monitorFieldOut").values.squeeze(),dtype=np.float16)[:395,:208,:1710]

# %%
AM.create_hdf5_from_dict({
    "data_field_intensities": data_field_intensities,
    "chi":np.array([0.2,0.3,0.31,0.32,0.33,0.34,0.35,0.36,0.37,0.38,0.39,0.4,0]),
    "sample":np.arange(0,20,1),
    "x":sim_result.sim_data.get_intensity("freq_monitorFieldOut").x.values[:395],
    "y":sim_result.sim_data.get_intensity("freq_monitorFieldOut").y.values[:208],
    "t":sim_result.sim_data.get_intensity("freq_monitorFieldOut").t.values[:1710],
},rf"F:\2D SHU Chi Statistics\data\10_04_2024 Beam Spreading Tight Bandwidth Periodic Conditions L=12\intensities_1.h5")

# %%
folder = rf"H:\phd stuff\tidy3d\data\10_04_2024 Beam Spreading Tight Bandwidth Periodic Conditions L=12"
       
data_field_intensities = np.zeros(shape=(12,1,20,555, 292, 2395),dtype=np.float16)

for i,item in enumerate(os.listdir(folder)):
    chi_path = os.path.join(folder, item)
    for j,item2 in enumerate(natsorted(os.listdir(chi_path))):
        if j == 2:
            chi_freq_folder=os.path.join(chi_path, item2)
            for k,item3 in enumerate(natsorted(os.listdir(chi_freq_folder))):
                file=os.path.join(chi_freq_folder, item3)
                old_stdout = sys.stdout
                sys.stdout = io.StringIO()
                try:
                    sim_result = (AM.loadFromFile(key = tidy3dAPI, file_path=file, save_path=rf"F:\2D SHU Chi Statistics",only_download=False,get_ref=False))
                finally:
                    # Reset sys.stdout back to the original state
                    sys.stdout = old_stdout

                data_field_intensities[i,j,k]=np.array(sim_result.sim_data.get_intensity("time_monitorFieldOut").values.squeeze(),dtype=np.float16)[:555,:292,:2395]

# %%
AM.create_hdf5_from_dict({
    "data_field_intensities": data_field_intensities,
    "chi":np.array([0.2,0.3,0.31,0.32,0.33,0.34,0.35,0.36,0.37,0.38,0.39,0.4,0]),
    "sample":np.arange(0,20,1),
    "x":sim_result.sim_data.get_intensity("freq_monitorFieldOut").x.values[:555],
    "y":sim_result.sim_data.get_intensity("freq_monitorFieldOut").y.values[:292],
    "t":sim_result.sim_data.get_intensity("freq_monitorFieldOut").t.values[:2395],
},rf"F:\2D SHU Chi Statistics\data\10_04_2024 Beam Spreading Tight Bandwidth Periodic Conditions L=12\intensities_2.h5")

# %%
folder = rf"H:\phd stuff\tidy3d\data\10_04_2024 Beam Spreading Tight Bandwidth Periodic Conditions L=12"
       
data_field_intensities = np.zeros(shape=(12,1,20,555, 292, 2395),dtype=np.float16)

for i,item in enumerate(os.listdir(folder)):
    chi_path = os.path.join(folder, item)
    for j,item2 in enumerate(natsorted(os.listdir(chi_path))):
        if j == 3:
            chi_freq_folder=os.path.join(chi_path, item2)
            for k,item3 in enumerate(natsorted(os.listdir(chi_freq_folder))):
                file=os.path.join(chi_freq_folder, item3)
                old_stdout = sys.stdout
                sys.stdout = io.StringIO()
                try:
                    sim_result = (AM.loadFromFile(key = tidy3dAPI, file_path=file, save_path=rf"F:\2D SHU Chi Statistics",only_download=False,get_ref=False))
                finally:
                    # Reset sys.stdout back to the original state
                    sys.stdout = old_stdout
                np.shape(sim_result.sim_data.get_intensity("time_monitorFieldOut").values.squeeze())
                data_field_intensities[i,j,k]=np.array(sim_result.sim_data.get_intensity("time_monitorFieldOut").values.squeeze(),dtype=np.float16)[:555,:292,:2395]
