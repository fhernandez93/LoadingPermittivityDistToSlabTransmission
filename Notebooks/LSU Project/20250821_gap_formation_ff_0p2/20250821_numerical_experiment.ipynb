# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy.io as sio
from dataclasses import dataclass
from typing import List, Tuple
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
from tidy3d import web
import numpy as np
from pathlib import Path
from stl import mesh
import matplotlib.pyplot as plt
import re

# %%
import sys
import os

# Assuming /AutomationModule is in the root directory of your project
sys.path.append(os.path.abspath(fr'H:\phd stuff\tidy3d'))

from AutomationModule import * 

import AutomationModule as AM

# %%
tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
lambdas = np.array([10,2.5])

# %%
folder_path = rf"D:\MPB Code and structures\20250731 New Structures res 256\Elongated"
project_name = "20250821 Florescu LSU Transmission T(L)"
postprocess_results = []
runtime_ps = 25e-12
min_steps_per_lambda = 20
cuts = [0.07,0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.8,0.9,1,1.2,1.3,1.5,1.7]
h5_bg = None
ref = True
for direction in ["z"]: 
    for dirpath, dirnames, filenames in os.walk(folder_path):
        try:
            n_value = float(re.search(r'n_([+-]?\d+(?:\.\d+)?)', dirpath).group(1))
            for filename in filenames:
                if filename.endswith(".h5") and "eps" in filename:
                    ff = float(re.search(r'ff_([+-]?\d+(?:\.\d+)?)', filename).group(1))
                    if ff == 0.2 and n_value>3.4:
                        print(dirpath, filename, n_value)
                        for cut in cuts:
                            if not (Path(filename).suffix==".h5" or Path(filename).suffix==".stl"):
                                continue 
                            if os.path.isfile(os.path.join(dirpath, filename)):
                                file=os.path.join(dirpath, filename)
                                structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                                                ,direction=direction, lambda_range=lambdas,
                                                                box_size=14.3,runtime_ps=runtime_ps,min_steps_per_lambda=min_steps_per_lambda,
                                                               scaling=1,shuoff_condtion=1e-20, verbose=True, 
                                                               monitors=["flux"], flux_monitor_position=18,cell_size_manual=45,
                                                               freqs=400, 
                                                               cut_condition=cut, source="planewave", absorbers=130, use_permittivity=False,sim_name=rf"{Path(filename).stem}_size_{cut}" + (rf"_bg_{h5_bg}" if h5_bg else ""),h5_bg=h5_bg,
                                                               )

                                folder_desc = rf"H:\phd stuff\tidy3d\data\{project_name}\n_{n_value:.2f}"
                                os.makedirs(folder_desc, exist_ok=True)
                                sim_name=rf"LSU_ff_{ff}_size_{cut}_n_{n_value:.2f}"
                                if os.path.exists(os.path.join(folder_desc, sim_name+".txt")):
                                    print("Exist!")
                                else:
                                    id =web.upload(structure_1.sim, folder_name=project_name,task_name=sim_name, verbose=True)
                                    # structure_1.plot_sim_layout()
                                    ids = '\n' + id
                                    with open(os.path.join(folder_desc, sim_name+".txt"), "w") as file:
                                        # Write the string to the file
                                        file.write(ids)
                                    web.start(task_id = id)
                                    # web.monitor(task_id=id,verbose=True)


                                del structure_1

                                # structure_1.estimate_cost()
                                # raise(Exception)


        except Exception as e:
            print(f"Error processing {dirpath}: {e}")
            continue
# Out:
# Error processing D:\MPB Code and structures\20250731 New Structures res 256\Elongated: 'NoneType' object has no attribute 'group'
# D:\MPB Code and structures\20250731 New Structures res 256\Elongated\structures_res_256_n_3.50_scaling_perp_0.4 ak4_1000_ends_rad_0.616_eps_ff_0.2000.h5 3.5
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# 13:03:47 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_1.7_n_3.50' with
#                                  task_id
#                                  'fdve-7bdefecc-e315-4455-8b9e-7c6b6586896e' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=378728;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bdefecc-e315-4455-8b9e-7c6b6586896e\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=150111;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bdefecc-e315-4455-8b9e-7c6b6586896e\task]8;;\
#                                  ]8;id=150111;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bdefecc-e315-4455-8b9e-7c6b6586896e\Id]8;;\]8;id=378728;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bdefecc-e315-4455-8b9e-7c6b6586896e\=]8;;\]8;id=592147;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bdefecc-e315-4455-8b9e-7c6b6586896e\fdve]8;;\]8;id=378728;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bdefecc-e315-4455-8b9e-7c6b6586896e\-7bdefecc-e315-4455-8b9e-7c6b6586896e']8;;\.
#                                  Task folder: ]8;id=306730;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=306730;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=963959;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=306730;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=963959;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=306730;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:04:54 W. Europe Daylight Time Maximum FlexCredit cost: 3.578. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# D:\MPB Code and structures\20250731 New Structures res 256\Elongated\structures_res_256_n_3.60_scaling_perp_0.4 ak4_1000_ends_rad_0.616_eps_ff_0.2000.h5 3.6
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# Configured successfully.
# Exist!
# D:\MPB Code and structures\20250731 New Structures res 256\Elongated\structures_res_256_n_3.70_scaling_perp_0.4 ak4_1000_ends_rad_0.616_eps_ff_0.2000.h5 3.7
# Configured successfully.
# Exist!
# Configured successfully.
# 13:05:28 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.1_n_3.70' with
#                                  task_id
#                                  'fdve-0b247296-2732-4bce-8f43-b4c8dd749ba1' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=610867;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0b247296-2732-4bce-8f43-b4c8dd749ba1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=462589;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0b247296-2732-4bce-8f43-b4c8dd749ba1\task]8;;\
#                                  ]8;id=462589;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0b247296-2732-4bce-8f43-b4c8dd749ba1\Id]8;;\]8;id=610867;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0b247296-2732-4bce-8f43-b4c8dd749ba1\=]8;;\]8;id=137186;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0b247296-2732-4bce-8f43-b4c8dd749ba1\fdve]8;;\]8;id=610867;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0b247296-2732-4bce-8f43-b4c8dd749ba1\-0b247296-2732-4bce-8f43-b4c8dd749ba1']8;;\.
#                                  Task folder: ]8;id=924652;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=924652;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=137074;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=924652;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=137074;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=924652;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:05:36 W. Europe Daylight Time Maximum FlexCredit cost: 2.826. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:05:39 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.2_n_3.70' with
#                                  task_id
#                                  'fdve-dc43f3a4-66f8-42f2-8046-711772c9918c' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=205020;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc43f3a4-66f8-42f2-8046-711772c9918c\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=969917;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc43f3a4-66f8-42f2-8046-711772c9918c\task]8;;\
#                                  ]8;id=969917;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc43f3a4-66f8-42f2-8046-711772c9918c\Id]8;;\]8;id=205020;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc43f3a4-66f8-42f2-8046-711772c9918c\=]8;;\]8;id=285724;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc43f3a4-66f8-42f2-8046-711772c9918c\fdve]8;;\]8;id=205020;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc43f3a4-66f8-42f2-8046-711772c9918c\-dc43f3a4-66f8-42f2-8046-711772c9918c']8;;\.
#                                  Task folder: ]8;id=920595;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=920595;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=167780;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=920595;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=167780;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=920595;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:05:54 W. Europe Daylight Time Maximum FlexCredit cost: 2.895. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:05:56 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.25_n_3.70' with
#                                  task_id
#                                  'fdve-a1862214-3d29-4078-b3a3-fd4655fe4a17' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=854986;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a1862214-3d29-4078-b3a3-fd4655fe4a17\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=447818;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a1862214-3d29-4078-b3a3-fd4655fe4a17\task]8;;\
#                                  ]8;id=447818;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a1862214-3d29-4078-b3a3-fd4655fe4a17\Id]8;;\]8;id=854986;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a1862214-3d29-4078-b3a3-fd4655fe4a17\=]8;;\]8;id=392688;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a1862214-3d29-4078-b3a3-fd4655fe4a17\fdve]8;;\]8;id=854986;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a1862214-3d29-4078-b3a3-fd4655fe4a17\-a1862214-3d29-4078-b3a3-fd4655fe4a17']8;;\.
#                                  Task folder: ]8;id=387448;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=387448;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=916822;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=387448;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=916822;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=387448;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:06:15 W. Europe Daylight Time Maximum FlexCredit cost: 2.964. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:06:17 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.3_n_3.70' with
#                                  task_id
#                                  'fdve-14510ab3-d676-4776-ae77-1a0c03e708cf' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=552629;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14510ab3-d676-4776-ae77-1a0c03e708cf\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=596833;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14510ab3-d676-4776-ae77-1a0c03e708cf\task]8;;\
#                                  ]8;id=596833;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14510ab3-d676-4776-ae77-1a0c03e708cf\Id]8;;\]8;id=552629;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14510ab3-d676-4776-ae77-1a0c03e708cf\=]8;;\]8;id=57004;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14510ab3-d676-4776-ae77-1a0c03e708cf\fdve]8;;\]8;id=552629;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14510ab3-d676-4776-ae77-1a0c03e708cf\-14510ab3-d676-4776-ae77-1a0c03e708cf']8;;\.
#                                  Task folder: ]8;id=738047;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=738047;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=526914;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=738047;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=526914;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=738047;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:06:39 W. Europe Daylight Time Maximum FlexCredit cost: 3.003. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:06:41 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.4_n_3.70' with
#                                  task_id
#                                  'fdve-3755b0a1-60fc-443c-8544-ee49ed948fed' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=251994;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3755b0a1-60fc-443c-8544-ee49ed948fed\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=31185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3755b0a1-60fc-443c-8544-ee49ed948fed\task]8;;\
#                                  ]8;id=31185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3755b0a1-60fc-443c-8544-ee49ed948fed\Id]8;;\]8;id=251994;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3755b0a1-60fc-443c-8544-ee49ed948fed\=]8;;\]8;id=230025;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3755b0a1-60fc-443c-8544-ee49ed948fed\fdve]8;;\]8;id=251994;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3755b0a1-60fc-443c-8544-ee49ed948fed\-3755b0a1-60fc-443c-8544-ee49ed948fed']8;;\.
#                                  Task folder: ]8;id=629215;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=629215;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=369795;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=629215;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=369795;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=629215;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:07:10 W. Europe Daylight Time Maximum FlexCredit cost: 3.084. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:07:12 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.5_n_3.70' with
#                                  task_id
#                                  'fdve-7b822164-eed3-44f7-ad6f-b4e76696c5b2' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=930279;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7b822164-eed3-44f7-ad6f-b4e76696c5b2\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=313890;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7b822164-eed3-44f7-ad6f-b4e76696c5b2\task]8;;\
#                                  ]8;id=313890;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7b822164-eed3-44f7-ad6f-b4e76696c5b2\Id]8;;\]8;id=930279;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7b822164-eed3-44f7-ad6f-b4e76696c5b2\=]8;;\]8;id=142004;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7b822164-eed3-44f7-ad6f-b4e76696c5b2\fdve]8;;\]8;id=930279;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7b822164-eed3-44f7-ad6f-b4e76696c5b2\-7b822164-eed3-44f7-ad6f-b4e76696c5b2']8;;\.
#                                  Task folder: ]8;id=457983;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=457983;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=901795;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=457983;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=901795;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=457983;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:07:47 W. Europe Daylight Time Maximum FlexCredit cost: 3.189. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:07:50 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.6_n_3.70' with
#                                  task_id
#                                  'fdve-8bc94712-9fc7-4bb7-87a1-d21a44430e69' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=619142;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bc94712-9fc7-4bb7-87a1-d21a44430e69\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=457927;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bc94712-9fc7-4bb7-87a1-d21a44430e69\task]8;;\
#                                  ]8;id=457927;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bc94712-9fc7-4bb7-87a1-d21a44430e69\Id]8;;\]8;id=619142;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bc94712-9fc7-4bb7-87a1-d21a44430e69\=]8;;\]8;id=285835;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bc94712-9fc7-4bb7-87a1-d21a44430e69\fdve]8;;\]8;id=619142;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bc94712-9fc7-4bb7-87a1-d21a44430e69\-8bc94712-9fc7-4bb7-87a1-d21a44430e69']8;;\.
#                                  Task folder: ]8;id=703755;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=703755;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=414301;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=703755;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=414301;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=703755;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:08:30 W. Europe Daylight Time Maximum FlexCredit cost: 3.271. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:08:33 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.7_n_3.70' with
#                                  task_id
#                                  'fdve-f800c628-580f-4fba-94ba-5b92d797cc74' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=94777;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f800c628-580f-4fba-94ba-5b92d797cc74\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=884524;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f800c628-580f-4fba-94ba-5b92d797cc74\task]8;;\
#                                  ]8;id=884524;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f800c628-580f-4fba-94ba-5b92d797cc74\Id]8;;\]8;id=94777;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f800c628-580f-4fba-94ba-5b92d797cc74\=]8;;\]8;id=248668;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f800c628-580f-4fba-94ba-5b92d797cc74\fdve]8;;\]8;id=94777;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f800c628-580f-4fba-94ba-5b92d797cc74\-f800c628-580f-4fba-94ba-5b92d797cc74']8;;\.
#                                  Task folder: ]8;id=693260;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=693260;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=82547;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=693260;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=82547;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=693260;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:09:20 W. Europe Daylight Time Maximum FlexCredit cost: 3.375. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:09:23 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.8_n_3.70' with
#                                  task_id
#                                  'fdve-8c55e3fc-320a-4404-9114-8166619b64ec' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=756016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8c55e3fc-320a-4404-9114-8166619b64ec\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=647661;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8c55e3fc-320a-4404-9114-8166619b64ec\task]8;;\
#                                  ]8;id=647661;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8c55e3fc-320a-4404-9114-8166619b64ec\Id]8;;\]8;id=756016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8c55e3fc-320a-4404-9114-8166619b64ec\=]8;;\]8;id=283002;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8c55e3fc-320a-4404-9114-8166619b64ec\fdve]8;;\]8;id=756016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8c55e3fc-320a-4404-9114-8166619b64ec\-8c55e3fc-320a-4404-9114-8166619b64ec']8;;\.
#                                  Task folder: ]8;id=902391;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=902391;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=669322;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=902391;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=669322;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=902391;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:10:14 W. Europe Daylight Time Maximum FlexCredit cost: 3.458. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:10:17 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_0.9_n_3.70' with
#                                  task_id
#                                  'fdve-cf5ad431-1dc2-4a3c-8587-e451e3925972' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=13014;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cf5ad431-1dc2-4a3c-8587-e451e3925972\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=303365;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cf5ad431-1dc2-4a3c-8587-e451e3925972\task]8;;\
#                                  ]8;id=303365;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cf5ad431-1dc2-4a3c-8587-e451e3925972\Id]8;;\]8;id=13014;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cf5ad431-1dc2-4a3c-8587-e451e3925972\=]8;;\]8;id=772288;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cf5ad431-1dc2-4a3c-8587-e451e3925972\fdve]8;;\]8;id=13014;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cf5ad431-1dc2-4a3c-8587-e451e3925972\-cf5ad431-1dc2-4a3c-8587-e451e3925972']8;;\.
#                                  Task folder: ]8;id=592221;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=592221;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=766762;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=592221;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=766762;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=592221;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:11:10 W. Europe Daylight Time Maximum FlexCredit cost: 3.551. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:11:13 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_1_n_3.70' with
#                                  task_id
#                                  'fdve-856163db-c2db-4a6d-b6fc-7345c2d24dd0' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=832200;https://tidy3d.simulation.cloud/workbench?taskId=fdve-856163db-c2db-4a6d-b6fc-7345c2d24dd0\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=864799;https://tidy3d.simulation.cloud/workbench?taskId=fdve-856163db-c2db-4a6d-b6fc-7345c2d24dd0\task]8;;\
#                                  ]8;id=864799;https://tidy3d.simulation.cloud/workbench?taskId=fdve-856163db-c2db-4a6d-b6fc-7345c2d24dd0\Id]8;;\]8;id=832200;https://tidy3d.simulation.cloud/workbench?taskId=fdve-856163db-c2db-4a6d-b6fc-7345c2d24dd0\=]8;;\]8;id=663414;https://tidy3d.simulation.cloud/workbench?taskId=fdve-856163db-c2db-4a6d-b6fc-7345c2d24dd0\fdve]8;;\]8;id=832200;https://tidy3d.simulation.cloud/workbench?taskId=fdve-856163db-c2db-4a6d-b6fc-7345c2d24dd0\-856163db-c2db-4a6d-b6fc-7345c2d24dd0']8;;\.
#                                  Task folder: ]8;id=525261;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=525261;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=305764;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=525261;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=305764;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=525261;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:12:11 W. Europe Daylight Time Maximum FlexCredit cost: 3.644. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:12:14 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_1.2_n_3.70' with
#                                  task_id
#                                  'fdve-120a592e-d06b-46d4-a742-d2e25a4500b9' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=157850;https://tidy3d.simulation.cloud/workbench?taskId=fdve-120a592e-d06b-46d4-a742-d2e25a4500b9\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=326162;https://tidy3d.simulation.cloud/workbench?taskId=fdve-120a592e-d06b-46d4-a742-d2e25a4500b9\task]8;;\
#                                  ]8;id=326162;https://tidy3d.simulation.cloud/workbench?taskId=fdve-120a592e-d06b-46d4-a742-d2e25a4500b9\Id]8;;\]8;id=157850;https://tidy3d.simulation.cloud/workbench?taskId=fdve-120a592e-d06b-46d4-a742-d2e25a4500b9\=]8;;\]8;id=377174;https://tidy3d.simulation.cloud/workbench?taskId=fdve-120a592e-d06b-46d4-a742-d2e25a4500b9\fdve]8;;\]8;id=157850;https://tidy3d.simulation.cloud/workbench?taskId=fdve-120a592e-d06b-46d4-a742-d2e25a4500b9\-120a592e-d06b-46d4-a742-d2e25a4500b9']8;;\.
#                                  Task folder: ]8;id=271786;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=271786;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=783730;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=271786;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=783730;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=271786;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:13:13 W. Europe Daylight Time Maximum FlexCredit cost: 3.830. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:13:16 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_1.3_n_3.70' with
#                                  task_id
#                                  'fdve-ae8da2bb-d071-4646-9e61-f0c83a633824' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=295977;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ae8da2bb-d071-4646-9e61-f0c83a633824\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=472500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ae8da2bb-d071-4646-9e61-f0c83a633824\task]8;;\
#                                  ]8;id=472500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ae8da2bb-d071-4646-9e61-f0c83a633824\Id]8;;\]8;id=295977;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ae8da2bb-d071-4646-9e61-f0c83a633824\=]8;;\]8;id=437175;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ae8da2bb-d071-4646-9e61-f0c83a633824\fdve]8;;\]8;id=295977;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ae8da2bb-d071-4646-9e61-f0c83a633824\-ae8da2bb-d071-4646-9e61-f0c83a633824']8;;\.
#                                  Task folder: ]8;id=757199;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=757199;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=517275;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=757199;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=517275;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=757199;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:14:16 W. Europe Daylight Time Maximum FlexCredit cost: 3.913. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:14:20 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_1.5_n_3.70' with
#                                  task_id
#                                  'fdve-02e1a3cf-173d-4544-8a05-cb1a8f3cdcf7' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=552684;https://tidy3d.simulation.cloud/workbench?taskId=fdve-02e1a3cf-173d-4544-8a05-cb1a8f3cdcf7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=962372;https://tidy3d.simulation.cloud/workbench?taskId=fdve-02e1a3cf-173d-4544-8a05-cb1a8f3cdcf7\task]8;;\
#                                  ]8;id=962372;https://tidy3d.simulation.cloud/workbench?taskId=fdve-02e1a3cf-173d-4544-8a05-cb1a8f3cdcf7\Id]8;;\]8;id=552684;https://tidy3d.simulation.cloud/workbench?taskId=fdve-02e1a3cf-173d-4544-8a05-cb1a8f3cdcf7\=]8;;\]8;id=153689;https://tidy3d.simulation.cloud/workbench?taskId=fdve-02e1a3cf-173d-4544-8a05-cb1a8f3cdcf7\fdve]8;;\]8;id=552684;https://tidy3d.simulation.cloud/workbench?taskId=fdve-02e1a3cf-173d-4544-8a05-cb1a8f3cdcf7\-02e1a3cf-173d-4544-8a05-cb1a8f3cdcf7']8;;\.
#                                  Task folder: ]8;id=706290;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=706290;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=884165;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=706290;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=884165;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=706290;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:15:27 W. Europe Daylight Time Maximum FlexCredit cost: 4.098. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# Configured successfully.
# 13:15:31 W. Europe Daylight Time Created task 'LSU_ff_0.2_size_1.7_n_3.70' with
#                                  task_id
#                                  'fdve-14b6f6ed-41b5-4992-816c-2f039973a9bc' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=865128;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14b6f6ed-41b5-4992-816c-2f039973a9bc\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=631942;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14b6f6ed-41b5-4992-816c-2f039973a9bc\task]8;;\
#                                  ]8;id=631942;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14b6f6ed-41b5-4992-816c-2f039973a9bc\Id]8;;\]8;id=865128;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14b6f6ed-41b5-4992-816c-2f039973a9bc\=]8;;\]8;id=844658;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14b6f6ed-41b5-4992-816c-2f039973a9bc\fdve]8;;\]8;id=865128;https://tidy3d.simulation.cloud/workbench?taskId=fdve-14b6f6ed-41b5-4992-816c-2f039973a9bc\-14b6f6ed-41b5-4992-816c-2f039973a9bc']8;;\.
#                                  Task folder: ]8;id=955924;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\'20250821 Florescu LSU ]8;;\
#                                  ]8;id=955924;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\Transmission T]8;;\]8;id=435599;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\(]8;;\]8;id=955924;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\L]8;;\]8;id=435599;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\)]8;;\]8;id=955924;https://tidy3d.simulation.cloud/folders/folder-742eda3e-7eb9-4237-ae3c-ae82272eb4c5\']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:16:39 W. Europe Daylight Time Maximum FlexCredit cost: 4.281. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
