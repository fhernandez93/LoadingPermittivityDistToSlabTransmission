# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy.io as sio
from dataclasses import dataclass
from typing import List, Tuple
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
from tidy3d import web
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from natsort import natsorted
import numpy as np
import matplotlib.animation as animation
import xarray as xr
import h5py
import imageio
import matplotlib
import gc
import sys
import io
import matplotlib.colors as mcolors
import matplotlib.patches as patches
from scipy.optimize import curve_fit
import scipy.integrate

import scipy.ndimage

# Assuming /AutomationModule is in the root directory of your project
sys.path.append(os.path.abspath(rf'H:\phd stuff\tidy3d'))

from AutomationModule import * 

import AutomationModule as AM
plt.rcParams.update({'font.size': 22})  

tidy3dAPI = os.environ["API_TIDY3D_KEY"]
plt.rc('font', family='Arial')

# %%
#Convergence

data = {}
for path_direction in [
                 
                  rf"H:\phd stuff\tidy3d\data\20250627 Far Field Transmission LSU 20p73_ff_5x_size_perm_10.89\z_incidence",
                       ]:
      folder_path = f"{path_direction}"
      
     
      for i,filename in enumerate(natsorted(os.listdir(folder_path))):
            print(filename)
           
            if not Path(filename).suffix==".txt":
                  continue
            if os.path.isfile(os.path.join(folder_path, filename)):
                  file=os.path.join(folder_path, filename)
                  structure_1 = AM.loadFromFile(key = tidy3dAPI, file_path=file)
                 
                  projected_field_data = structure_1.sim_data["far_field"].power.squeeze().values
                  if filename not in data.keys():
                        data[filename] = {}

                  data[filename] =structure_1.sim_data["far_field"].power.squeeze().values
# Out:
# ak4_1000_ends_rad_0.65_eps_ff_0.2073_size_0.47.txt
# Configured successfully.
# 05:22:01 W. Europe Daylight Time ERROR: The request was rejected because the URL
#                                  contained a potentially malicious String "//"
# No Reference Simulation was found for this case
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 05:31:30 W. Europe Daylight Time loading simulation from H:\phd
#                                  stuff\tidy3d/output/data\20250627 Far Field
#                                  Transmission LSU
#                                  20p73_ff_5x_size_perm_10.89\z_incidence\ak4_100
#                                  0_ends_rad_0.65_eps_ff_0.2073_size_0.47.txt/Dat
#                                  a.hdf5
# 05:31:42 W. Europe Daylight Time WARNING: Structure at 'structures[0]' has
#                                  bounds that extend exactly to simulation edges.
#                                  This can cause unexpected behavior. If
#                                  intending to extend the structure to infinity
#                                  along one dimension, use td.inf as a size
#                                  variable instead to make this explicit.
#                                  WARNING: Suppressed 19 WARNING messages.
#                                  WARNING: Field projection monitor 'far_field'
#                                  has observation points set up such that the
#                                  monitor is projecting backwards with respect to
#                                  its 'normal_dir'. If this was not intentional,
#                                  please take a look at the documentation
#                                  associated with this type of projection monitor
#                                  to check how the observation point coordinate
#                                  system is defined.
# 05:34:13 W. Europe Daylight Time WARNING: Simulation final field decay value of
#                                  3.37e-10 is greater than the simulation shutoff
#                                  threshold of 1e-20. Consider running the
#                                  simulation again with a larger 'run_time'
#                                  duration for more accurate results.
#                                  WARNING: Warning messages were found in the
#                                  solver log. For more information, check
#                                  'SimulationData.log' or use
#                                  'web.download_log(task_id)'.
# 05:34:14 W. Europe Daylight Time Billed flex credit cost: 113.094.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.
# ak4_1000_ends_rad_0.65_eps_ff_0.2073_size_0.82.txt
# Configured successfully.
# 05:34:44 W. Europe Daylight Time ERROR: The request was rejected because the URL
#                                  contained a potentially malicious String "//"
# No Reference Simulation was found for this case
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 05:45:10 W. Europe Daylight Time loading simulation from H:\phd
#                                  stuff\tidy3d/output/data\20250627 Far Field
#                                  Transmission LSU
#                                  20p73_ff_5x_size_perm_10.89\z_incidence\ak4_100
#                                  0_ends_rad_0.65_eps_ff_0.2073_size_0.82.txt/Dat
#                                  a.hdf5
# 05:45:28 W. Europe Daylight Time WARNING: Structure at 'structures[0]' has
#                                  bounds that extend exactly to simulation edges.
#                                  This can cause unexpected behavior. If
#                                  intending to extend the structure to infinity
#                                  along one dimension, use td.inf as a size
#                                  variable instead to make this explicit.
#                                  WARNING: Suppressed 19 WARNING messages.
#                                  WARNING: Field projection monitor 'far_field'
#                                  has observation points set up such that the
#                                  monitor is projecting backwards with respect to
#                                  its 'normal_dir'. If this was not intentional,
#                                  please take a look at the documentation
#                                  associated with this type of projection monitor
#                                  to check how the observation point coordinate
#                                  system is defined.
# 05:49:54 W. Europe Daylight Time WARNING: Simulation final field decay value of
#                                  3.38e-10 is greater than the simulation shutoff
#                                  threshold of 1e-20. Consider running the
#                                  simulation again with a larger 'run_time'
#                                  duration for more accurate results.
#                                  WARNING: Warning messages were found in the
#                                  solver log. For more information, check
#                                  'SimulationData.log' or use
#                                  'web.download_log(task_id)'.
# 05:49:55 W. Europe Daylight Time Billed flex credit cost: 115.011.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.
# ak4_1000_ends_rad_0.65_eps_ff_0.2073_size_1.txt
# Configured successfully.
# 05:50:25 W. Europe Daylight Time ERROR: The request was rejected because the URL
#                                  contained a potentially malicious String "//"
# No Reference Simulation was found for this case
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 06:01:27 W. Europe Daylight Time loading simulation from H:\phd
#                                  stuff\tidy3d/output/data\20250627 Far Field
#                                  Transmission LSU
#                                  20p73_ff_5x_size_perm_10.89\z_incidence\ak4_100
#                                  0_ends_rad_0.65_eps_ff_0.2073_size_1.txt/Data.h
#                                  df5
# 06:01:57 W. Europe Daylight Time WARNING: Structure at 'structures[0]' has
#                                  bounds that extend exactly to simulation edges.
#                                  This can cause unexpected behavior. If
#                                  intending to extend the structure to infinity
#                                  along one dimension, use td.inf as a size
#                                  variable instead to make this explicit.
#                                  WARNING: Suppressed 19 WARNING messages.
#                                  WARNING: Field projection monitor 'far_field'
#                                  has observation points set up such that the
#                                  monitor is projecting backwards with respect to
#                                  its 'normal_dir'. If this was not intentional,
#                                  please take a look at the documentation
#                                  associated with this type of projection monitor
#                                  to check how the observation point coordinate
#                                  system is defined.
# 06:07:26 W. Europe Daylight Time WARNING: Simulation final field decay value of
#                                  3.39e-10 is greater than the simulation shutoff
#                                  threshold of 1e-20. Consider running the
#                                  simulation again with a larger 'run_time'
#                                  duration for more accurate results.
#                                  WARNING: Warning messages were found in the
#                                  solver log. For more information, check
#                                  'SimulationData.log' or use
#                                  'web.download_log(task_id)'.
# 06:07:27 W. Europe Daylight Time Billed flex credit cost: 115.964.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.
# reference.txt
# Configured successfully.
# 06:07:58 W. Europe Daylight Time ERROR: The request was rejected because the URL
#                                  contained a potentially malicious String "//"
# No Reference Simulation was found for this case
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 06:15:51 W. Europe Daylight Time loading simulation from H:\phd
#                                  stuff\tidy3d/output/data\20250627 Far Field
#                                  Transmission LSU
#                                  20p73_ff_5x_size_perm_10.89\z_incidence\referen
#                                  ce.txt/Data.hdf5
# 06:15:56 W. Europe Daylight Time WARNING: Field projection monitor 'far_field'
#                                  has observation points set up such that the
#                                  monitor is projecting backwards with respect to
#                                  its 'normal_dir'. If this was not intentional,
#                                  please take a look at the documentation
#                                  associated with this type of projection monitor
#                                  to check how the observation point coordinate
#                                  system is defined.
#                                  WARNING: Simulation final field decay value of
#                                  3.49e-10 is greater than the simulation shutoff
#                                  threshold of 1e-20. Consider running the
#                                  simulation again with a larger 'run_time'
#                                  duration for more accurate results.
#                                  WARNING: Warning messages were found in the
#                                  solver log. For more information, check
#                                  'SimulationData.log' or use
#                                  'web.download_log(task_id)'.
#                                  Billed flex credit cost: 29.674.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.

# %%
create_hdf5_from_dict(data,"20250627_far_field_eps_10p89_ff_20p73.h5")

# %%
r_proj=(structure_1.sim_data["far_field"].r)
theta_proj=structure_1.sim_data["far_field"].theta
phi_proj=structure_1.sim_data["far_field"].phi
lambdas = (td.C_0/structure_1.sim_data["far_field"].f)

data_parameters = {
    "r_proj":r_proj,
    "theta_proj":theta_proj,
    "phi_proj":phi_proj,
    "lambdas":lambdas
}

create_hdf5_from_dict(data_parameters,"20250627_far_field_eps_10p89_ff_20p73_params.h5")
