# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy.io as sio
from dataclasses import dataclass
from typing import List, Tuple
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
from tidy3d import web
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from natsort import natsorted
import numpy as np
import matplotlib.animation as animation
import xarray as xr
import h5py
import imageio
import matplotlib
import gc
import sys
import io
import matplotlib.colors as mcolors
import matplotlib.patches as patches
from scipy.optimize import curve_fit
import scipy.integrate

import scipy.ndimage

# Assuming /AutomationModule is in the root directory of your project
sys.path.append(os.path.abspath(rf'H:\phd stuff\tidy3d'))

from AutomationModule import * 

import AutomationModule as AM
plt.rcParams.update({'font.size': 22})  

tidy3dAPI = os.environ["API_TIDY3D_KEY"]
plt.rc('font', family='Arial')

# %%
#Convergence

data = {}
for path_direction in [
                 
                  # rf"H:\phd stuff\tidy3d\data\20250627 Far Field Transmission LSU 20p73_ff_5x_size_perm_10.89\z_incidence",
                  # rf"H:\phd stuff\tidy3d\data\20250627 Far Field Transmission LSU ff_20p45_5x_size_perm_10.89\z_incidence"
                  # rf"H:\phd stuff\tidy3d\data\20250715 Far Field Transmission LSU ff_20p45_5x_size_perm_10.24\z_incidence"
                  # rf"H:\phd stuff\tidy3d\data\20250925 Far Field Transmission LSU ff_20p45_5x_size_perm_10.24\z_incidence"
                  rf"H:\phd stuff\tidy3d\data\20251006 Far Field Transmission LSU ff_21p72_5x_size_perm_8.57\z_incidence"
                       ]:
      folder_path = f"{path_direction}"
      
     
      for i,filename in enumerate(natsorted(os.listdir(folder_path))):
            sim_name = Path(filename).stem
            print(sim_name)
           
            if not Path(filename).suffix==".txt":
                  continue
            if os.path.isfile(os.path.join(folder_path, filename)):
                  file=os.path.join(folder_path, filename)
                  structure_1 = AM.loadFromFile(key = tidy3dAPI, file_path=file)
                 
                  # projected_field_data = structure_1.sim_data["far_field"].power.squeeze().values
                  if sim_name not in data.keys():
                        data[sim_name] = {}

                  # data[sim_name] =structure_1.sim_data["far_field"].power.squeeze().values
                  data[sim_name]["Etheta"] = structure_1.sim_data["far_field"].Etheta.squeeze().values
                  data[sim_name]["Ephi"] = structure_1.sim_data["far_field"].Ephi.squeeze().values
# Out:
# n_2.9275_ff_0.2172_size_0.6118881118881119
# Configured successfully.
# No Reference Simulation was loaded
# 09:31:19 W. Europe Standard Time WARNING: Structure at 'structures[0]' has
#                                  bounds that extend exactly to simulation edges.
#                                  This can cause unexpected behavior. If
#                                  intending to extend the structure to infinity
#                                  along one dimension, use td.inf as a size
#                                  variable instead to make this explicit.
#                                  WARNING: Suppressed 19 WARNING messages.
# 09:31:20 W. Europe Standard Time WARNING: Field projection monitor 'far_field'
#                                  has observation points set up such that the
#                                  monitor is projecting backwards with respect to
#                                  its 'normal_dir'. If this was not intentional,
#                                  please take a look at the documentation
#                                  associated with this type of projection monitor
#                                  to check how the observation point coordinate
#                                  system is defined.
# 09:33:24 W. Europe Standard Time Billed flex credit cost: 96.293.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.
# n_2.9275_ff_0.2172_size_0.6993006993006993
# Configured successfully.
# No Reference Simulation was loaded
# 09:33:47 W. Europe Standard Time WARNING: Structure at 'structures[0]' has
#                                  bounds that extend exactly to simulation edges.
#                                  This can cause unexpected behavior. If
#                                  intending to extend the structure to infinity
#                                  along one dimension, use td.inf as a size
#                                  variable instead to make this explicit.
# 09:33:48 W. Europe Standard Time WARNING: Suppressed 19 WARNING messages.
#                                  WARNING: Field projection monitor 'far_field'
#                                  has observation points set up such that the
#                                  monitor is projecting backwards with respect to
#                                  its 'normal_dir'. If this was not intentional,
#                                  please take a look at the documentation
#                                  associated with this type of projection monitor
#                                  to check how the observation point coordinate
#                                  system is defined.
# 09:36:10 W. Europe Standard Time Billed flex credit cost: 96.576.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.
# n_2.9275_ff_0.2172_size_0.7867132867132867
# Configured successfully.
# No Reference Simulation was loaded
# 09:36:34 W. Europe Standard Time WARNING: Structure at 'structures[0]' has
#                                  bounds that extend exactly to simulation edges.
#                                  This can cause unexpected behavior. If
#                                  intending to extend the structure to infinity
#                                  along one dimension, use td.inf as a size
#                                  variable instead to make this explicit.
#                                  WARNING: Suppressed 19 WARNING messages.
#                                  WARNING: Field projection monitor 'far_field'
#                                  has observation points set up such that the
#                                  monitor is projecting backwards with respect to
#                                  its 'normal_dir'. If this was not intentional,
#                                  please take a look at the documentation
#                                  associated with this type of projection monitor
#                                  to check how the observation point coordinate
#                                  system is defined.
# 09:39:13 W. Europe Standard Time Billed flex credit cost: 96.942.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.
# n_2.9275_ff_0.2172_size_0.8741258741258741
# Configured successfully.
# No Reference Simulation was loaded
# 09:39:39 W. Europe Standard Time WARNING: Structure at 'structures[0]' has
#                                  bounds that extend exactly to simulation edges.
#                                  This can cause unexpected behavior. If
#                                  intending to extend the structure to infinity
#                                  along one dimension, use td.inf as a size
#                                  variable instead to make this explicit.
#                                  WARNING: Suppressed 19 WARNING messages.
#                                  WARNING: Field projection monitor 'far_field'
#                                  has observation points set up such that the
#                                  monitor is projecting backwards with respect to
#                                  its 'normal_dir'. If this was not intentional,
#                                  please take a look at the documentation
#                                  associated with this type of projection monitor
#                                  to check how the observation point coordinate
#                                  system is defined.
# 09:42:37 W. Europe Standard Time Billed flex credit cost: 97.290.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.
# n_2.9275_ff_0.2172_size_0.34965034965034963
# Configured successfully.
# No Reference Simulation was loaded
# 09:42:55 W. Europe Standard Time WARNING: Structure at 'structures[0]' has
#                                  bounds that extend exactly to simulation edges.
#                                  This can cause unexpected behavior. If
#                                  intending to extend the structure to infinity
#                                  along one dimension, use td.inf as a size
#                                  variable instead to make this explicit.
#                                  WARNING: Suppressed 19 WARNING messages.
#                                  WARNING: Field projection monitor 'far_field'
#                                  has observation points set up such that the
#                                  monitor is projecting backwards with respect to
#                                  its 'normal_dir'. If this was not intentional,
#                                  please take a look at the documentation
#                                  associated with this type of projection monitor
#                                  to check how the observation point coordinate
#                                  system is defined.
# 09:44:05 W. Europe Standard Time Billed flex credit cost: 95.215.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.

# %%
create_hdf5_from_dict(data,"./data/20251006_far_field_eps_8p57_ff_21p72_air.h5")

# %%
# r_proj=(structure_1.sim_data["far_field"].r)
# theta_proj=structure_1.sim_data["far_field"].theta
# phi_proj=structure_1.sim_data["far_field"].phi
# lambdas = (td.C_0/structure_1.sim_data["far_field"].f)

# data_parameters = {
#     "r_proj":r_proj,
#     "theta_proj":theta_proj,
#     "phi_proj":phi_proj,
#     "lambdas":lambdas
# }

# create_hdf5_from_dict(data_parameters,"20250708_far_field_eps_10p89_ff_20p45_decaline_and_air_params.h5")
