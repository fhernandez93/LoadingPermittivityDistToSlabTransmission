# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy.io as sio
from dataclasses import dataclass
from typing import List, Tuple
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
from tidy3d import web
import numpy as np
from pathlib import Path
from stl import mesh
import matplotlib.pyplot as plt
import re

# %%
import sys
import os

# Assuming /AutomationModule is in the root directory of your project
sys.path.append(os.path.abspath(fr'H:\phd stuff\tidy3d'))

from AutomationModule import * 

import AutomationModule as AM

# %%
tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
lambdas = np.array([8,2])

# %%
folder_path = rf"./Structures"
project_name = "20260511 LSU Generated Comparison"
postprocess_results = []
runtime_ps = 25e-12
min_steps_per_lambda = 20
h5_bg = None
ref = True
cuts=np.array([1])
for direction in ["z"]: 
    for dirpath, dirnames, filenames in os.walk(folder_path):
        print(f"Processing directory: {dirpath}")
        try:
            for filename in filenames:
                print(filename)
                if filename.endswith(".h5"):
                    for cut in cuts:
                        if not (Path(filename).suffix==".h5" or Path(filename).suffix==".stl"):
                            continue 
                        if os.path.isfile(os.path.join(dirpath, filename)):
                            file=os.path.join(dirpath, filename)
                            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                                            ,direction=direction, lambda_range=lambdas,
                                                            box_size=11.44,runtime_ps=runtime_ps,min_steps_per_lambda=min_steps_per_lambda,
                                                           scaling=1,shuoff_condtion=1e-20, verbose=True, 
                                                           monitors=["flux"], flux_monitor_position=18,cell_size_manual=44,
                                                           freqs=400, 
                                                           cut_condition=cut, source="planewave", absorbers=130, use_permittivity=False,sim_name=rf"{Path(filename).stem}_size_{cut}" + (rf"_bg_{h5_bg}" if h5_bg else ""),h5_bg=h5_bg,
                                                           )
                            folder_desc = rf"H:\phd stuff\tidy3d\data\{project_name}"
                            os.makedirs(folder_desc, exist_ok=True)
                            sim_name=rf"{Path(filename).stem}_size_{cut}_n_{np.sqrt(structure_1.permittivity_value):.2f}"
                            
                            if os.path.exists(os.path.join(folder_desc, sim_name+".txt")):
                                print("Exist!")
                            else:
                                if ref:
                                 sim0=(structure_1.sim).copy(update={"structures":[]})
                                 id0 =web.upload(sim0, folder_name=project_name,task_name=sim_name+"_0", verbose=True)
                                 web.start(task_id = id0)
                                 web.monitor(task_id=id0,verbose=True)
                                 with open(os.path.join(folder_desc, "reference.txt"), "w") as file:
                                    # Write the string to the file
                                    file.write('\n'+id0)
                                 ref=False

                                id =web.upload(structure_1.sim, folder_name=project_name,task_name=sim_name, verbose=True)
                                structure_1.plot_sim_layout()
                                ids = '\n' + id
                                with open(os.path.join(folder_desc, sim_name+".txt"), "w") as file:
                                    # Write the string to the file
                                    file.write(ids)
                                web.start(task_id = id)
                                web.monitor(task_id=id,verbose=True)
                            del structure_1

        except Exception as e:
            print(f"Error processing {dirpath}: {e}")
            continue
# Out:
# Processing directory: ./Structures
# 20260512_lsu_generated_2.h5
# Configured successfully.
# 10:23:55 W. Europe Daylight Time Created task
#                                  '20260512_lsu_generated_2_size_1_n_2.93_0' with
#                                  task_id
#                                  'fdve-27364ef9-f14f-44a5-8d11-fb965ed2e7ad' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=950494;https://tidy3d.simulation.cloud/workbench?taskId=fdve-27364ef9-f14f-44a5-8d11-fb965ed2e7ad\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=671155;https://tidy3d.simulation.cloud/workbench?taskId=fdve-27364ef9-f14f-44a5-8d11-fb965ed2e7ad\task]8;;\
#                                  ]8;id=671155;https://tidy3d.simulation.cloud/workbench?taskId=fdve-27364ef9-f14f-44a5-8d11-fb965ed2e7ad\Id]8;;\]8;id=950494;https://tidy3d.simulation.cloud/workbench?taskId=fdve-27364ef9-f14f-44a5-8d11-fb965ed2e7ad\=]8;;\]8;id=671628;https://tidy3d.simulation.cloud/workbench?taskId=fdve-27364ef9-f14f-44a5-8d11-fb965ed2e7ad\fdve]8;;\]8;id=950494;https://tidy3d.simulation.cloud/workbench?taskId=fdve-27364ef9-f14f-44a5-8d11-fb965ed2e7ad\-27364ef9-f14f-44a5-8d11-fb965ed2e7ad']8;;\.
#                                  Task folder: ]8;id=79354;https://tidy3d.simulation.cloud/folders/folder-b82c9435-9bee-40da-857c-32622e35073d\'20260511 LSU Generated ]8;;\
#                                  ]8;id=79354;https://tidy3d.simulation.cloud/folders/folder-b82c9435-9bee-40da-857c-32622e35073d\Comparison']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 10:23:57 W. Europe Daylight Time Maximum FlexCredit cost: 0.095. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 10:23:58 W. Europe Daylight Time status = success
# 10:23:59 W. Europe Daylight Time Created task
#                                  '20260512_lsu_generated_2_size_1_n_2.93' with
#                                  task_id
#                                  'fdve-557c9f83-05cc-406c-af38-a15db3514329' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=793365;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=221051;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\task]8;;\
#                                  ]8;id=221051;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\Id]8;;\]8;id=793365;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\=]8;;\]8;id=408184;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\fdve]8;;\]8;id=793365;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\-557c9f83-05cc-406c-af38-a15db3514329']8;;\.
#                                  Task folder: ]8;id=885127;https://tidy3d.simulation.cloud/folders/folder-b82c9435-9bee-40da-857c-32622e35073d\'20260511 LSU Generated ]8;;\
#                                  ]8;id=885127;https://tidy3d.simulation.cloud/folders/folder-b82c9435-9bee-40da-857c-32622e35073d\Comparison']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 10:24:38 W. Europe Daylight Time Maximum FlexCredit cost: 2.323. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 10:24:48 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# 10:24:59 W. Europe Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:25:06 W. Europe Daylight Time starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# 10:32:33 W. Europe Daylight Time status = postprocess
# 10:32:38 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:32:40 W. Europe Daylight Time View simulation result at
#                                  ]8;id=771247;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=585809;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\task]8;;\
#                                  ]8;id=585809;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\Id]8;;\]8;id=771247;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\=]8;;\]8;id=733485;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\fdve]8;;\]8;id=771247;https://tidy3d.simulation.cloud/workbench?taskId=fdve-557c9f83-05cc-406c-af38-a15db3514329\-557c9f83-05cc-406c-af38-a15db3514329']8;;\.
# 20260512_lsu_generated_2.txt
# 20260512_lsu_generated_2.vtk
# lsu_example.h5
# Configured successfully.
# 10:32:46 W. Europe Daylight Time Created task 'lsu_example_size_1_n_2.93' with
#                                  task_id
#                                  'fdve-2a5f7764-b55a-4d81-8252-f009665141d6' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=592531;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=786185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\task]8;;\
#                                  ]8;id=786185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\Id]8;;\]8;id=592531;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\=]8;;\]8;id=92821;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\fdve]8;;\]8;id=592531;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\-2a5f7764-b55a-4d81-8252-f009665141d6']8;;\.
#                                  Task folder: ]8;id=683536;https://tidy3d.simulation.cloud/folders/folder-b82c9435-9bee-40da-857c-32622e35073d\'20260511 LSU Generated ]8;;\
#                                  ]8;id=683536;https://tidy3d.simulation.cloud/folders/folder-b82c9435-9bee-40da-857c-32622e35073d\Comparison']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 10:33:34 W. Europe Daylight Time Maximum FlexCredit cost: 2.323. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 10:33:43 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# 10:33:57 W. Europe Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:34:01 W. Europe Daylight Time starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 10:40:41 W. Europe Daylight Time status = postprocess
# Output()
# 10:40:48 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:40:50 W. Europe Daylight Time View simulation result at
#                                  ]8;id=378481;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=752016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\task]8;;\
#                                  ]8;id=752016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\Id]8;;\]8;id=378481;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\=]8;;\]8;id=917571;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\fdve]8;;\]8;id=378481;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2a5f7764-b55a-4d81-8252-f009665141d6\-2a5f7764-b55a-4d81-8252-f009665141d6']8;;\.
# lsu_example.vtk
# lsu_example_ends.txt
