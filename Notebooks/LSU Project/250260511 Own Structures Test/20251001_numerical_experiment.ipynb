# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from dotenv import load_dotenv
load_dotenv()
import re

# %%
import sys
import os

# Assuming /AutomationModule is in the root directory of your project
sys.path.append(os.path.abspath(fr'../../../../tidy3d'))

from AutomationModule import * 

import AutomationModule as AM

# %%
tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
lambdas = np.array([8,2])

# %%
folder_path = rf"./Structures/h5"
project_name = "20260629 LSU Generated Comparison"
postprocess_results = []
runtime_ps = 25e-12
min_steps_per_lambda = 20
h5_bg = None
ref = True
cuts=np.array([1])
for direction in ["z"]: 
    for dirpath, dirnames, filenames in os.walk(folder_path):
        print(f"Processing directory: {dirpath}")
        try:
            for filename in filenames:
                print(filename)
                if filename.endswith(".h5"):
                    D0, N  = 0.8, int(re.search(r'N_(\d+)',filename).group(1))
                    BOX_SIZE = (N/1000 * 11.44**3)**(1/3)  # Size of the simulation box in each dimension
                    for cut in cuts:
                        if not (Path(filename).suffix==".h5" or Path(filename).suffix==".stl"):
                            continue 
                        if os.path.isfile(os.path.join(dirpath, filename)):
                            file=os.path.join(dirpath, filename)
                            structure_1 = AM.loadAndRunStructure(key = tidy3dAPI, file_path=file
                                                            ,direction=direction, lambda_range=lambdas,
                                                            box_size=BOX_SIZE,runtime_ps=runtime_ps,min_steps_per_lambda=min_steps_per_lambda,
                                                           scaling=1,shuoff_condtion=1e-20, verbose=True, 
                                                           monitors=["flux"], flux_monitor_position=18,cell_size_manual=44,
                                                           freqs=400, 
                                                           cut_condition=cut, source="planewave", absorbers=130, use_permittivity=False,sim_name=rf"{Path(filename).stem}_size_{cut}" + (rf"_bg_{h5_bg}" if h5_bg else ""),h5_bg=h5_bg,
                                                           )
                            folder_desc = rf"../../../data/{project_name}"
                            os.makedirs(folder_desc, exist_ok=True)
                            sim_name=rf"{Path(filename).stem}_size_{cut}_n_{np.sqrt(structure_1.permittivity_value):.2f}"
                            
                            if os.path.exists(os.path.join(folder_desc, sim_name+".txt")):
                                print("Exist!")
                            else:
                                if ref:
                                 sim0=(structure_1.sim).copy(update={"structures":[]})
                                 id0 =web.upload(sim0, folder_name=project_name,task_name=sim_name+"_0", verbose=True)
                                 web.start(task_id = id0)
                                 web.monitor(task_id=id0,verbose=True)
                                 with open(os.path.join(folder_desc, "reference.txt"), "w") as file:
                                    # Write the string to the file
                                    file.write('\n'+id0)
                                 ref=False

                                id =web.upload(structure_1.sim, folder_name=project_name,task_name=sim_name, verbose=True)
                                structure_1.plot_sim_layout()
                                ids = '\n' + id
                                with open(os.path.join(folder_desc, sim_name+".txt"), "w") as file:
                                    # Write the string to the file
                                    file.write(ids)
                                web.start(task_id = id)
                                web.monitor(task_id=id,verbose=True)
                            del structure_1

        except Exception as e:
            print(f"Error processing {dirpath}: {e}")
            continue
# Out:
# Processing directory: ./Structures/h5
# N_4000_n_2.9000_ff_0.2233_res_600.h5
# Configured successfully.
# 13:32:10 W. Europe Daylight Time Created task
#                                  'N_4000_n_2.9000_ff_0.2233_res_600_size_1_n_2.9
#                                  0_0' with task_id
#                                  'fdve-64aa0553-b93f-47ad-b134-569494dbae46' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=152617;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=379149;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\task]8;;\
#                                  ]8;id=379149;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\Id]8;;\]8;id=152617;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\=]8;;\]8;id=119457;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\fdve]8;;\]8;id=152617;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\-64aa0553-b93f-47ad-b134-569494dbae46']8;;\.
#                                  Task folder: ]8;id=62493;https://tidy3d.simulation.cloud/folders/folder-1aeb96a5-f6be-4302-abc3-cdb2fee45a34\'20260629 LSU Generated ]8;;\
#                                  ]8;id=62493;https://tidy3d.simulation.cloud/folders/folder-1aeb96a5-f6be-4302-abc3-cdb2fee45a34\Comparison']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:32:20 W. Europe Daylight Time Maximum FlexCredit cost: 0.238. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 13:32:21 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 13:32:33 W. Europe Daylight Time starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:34:15 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  View simulation result at
#                                  ]8;id=856388;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=705503;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\task]8;;\
#                                  ]8;id=705503;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\Id]8;;\]8;id=856388;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\=]8;;\]8;id=530689;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\fdve]8;;\]8;id=856388;https://tidy3d.simulation.cloud/workbench?taskId=fdve-64aa0553-b93f-47ad-b134-569494dbae46\-64aa0553-b93f-47ad-b134-569494dbae46']8;;\.
#                                  Created task
#                                  'N_4000_n_2.9000_ff_0.2233_res_600_size_1_n_2.9
#                                  0' with task_id
#                                  'fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=608385;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=405732;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\task]8;;\
#                                  ]8;id=405732;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\Id]8;;\]8;id=608385;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\=]8;;\]8;id=718907;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\fdve]8;;\]8;id=608385;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\-afe3c874-bdb8-42ca-9de1-d5355fe4f34b']8;;\.
#                                  Task folder: ]8;id=891098;https://tidy3d.simulation.cloud/folders/folder-1aeb96a5-f6be-4302-abc3-cdb2fee45a34\'20260629 LSU Generated ]8;;\
#                                  ]8;id=891098;https://tidy3d.simulation.cloud/folders/folder-1aeb96a5-f6be-4302-abc3-cdb2fee45a34\Comparison']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:35:21 W. Europe Daylight Time Maximum FlexCredit cost: 6.034. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 13:35:35 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# 13:35:58 W. Europe Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 13:36:09 W. Europe Daylight Time starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 13:42:33 W. Europe Daylight Time status = postprocess
# Output()
# 13:42:49 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 13:42:51 W. Europe Daylight Time View simulation result at
#                                  ]8;id=163512;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=251024;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\task]8;;\
#                                  ]8;id=251024;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\Id]8;;\]8;id=163512;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\=]8;;\]8;id=749336;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\fdve]8;;\]8;id=163512;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afe3c874-bdb8-42ca-9de1-d5355fe4f34b\-afe3c874-bdb8-42ca-9de1-d5355fe4f34b']8;;\.
