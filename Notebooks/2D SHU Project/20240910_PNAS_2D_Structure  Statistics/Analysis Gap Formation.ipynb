# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy.io as sio
from dataclasses import dataclass
from typing import List, Tuple
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
from tidy3d import web
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from natsort import natsorted

# %%
import sys
import os

# Assuming /AutomationModule is in the root directory of your project
sys.path.append(os.path.abspath(rf'H:\phd stuff\tidy3d'))

from AutomationModule import * 

import AutomationModule as AM

# %%
tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
a = 1

# %%
# folder_path = rf"H:\phd stuff\tidy3d\data\09_16_2024 Gap Revision"
# folder_path = rf"H:\phd stuff\tidy3d\data\09_13_2024 Beam Spreading 0.24 - 0.44 Average"
folder_path = rf"H:\phd stuff\tidy3d\data\09_13_2024 Beam Spreading 0.24 - 0.44 Average Periodic Conditions"
transmitted_fluxes = []
for i,foldername in enumerate(natsorted(os.listdir(folder_path))):
        intensities = []
        xis = []
        print(foldername)
        file=os.path.join(folder_path, foldername)
        samples = []
        plt.figure(figsize=(15, 10))
        for j,filename in enumerate(natsorted(os.listdir(file))):
            print(filename)
            file_local=os.path.join(file, filename)
            sim_object_result = AM.loadFromFile(key = tidy3dAPI, file_path=file_local)
            sim_data = sim_object_result.sim_data
            try:
                sim_data0 = sim_object_result.sim_data0
            except:
                 sim_data0 = web.load("fdve-f8184acf-052d-49eb-b558-b6e410718815")
            transmission0 = sim_data0['flux1'].flux
            transmission = sim_data['flux1'].flux
            transmission_left0 = sim_data0['flux2'].flux
            transmission_left = sim_data['flux2'].flux
            transmission_normalized_left = transmission_left / transmission_left0
            transmission_normalized = transmission / transmission0
            transmitted_fluxes += [transmission_normalized]
            monitor_lambdas = a/(td.C_0/np.array(np.array(sim_data.simulation.monitors)[2].freqs))

            plt.plot(monitor_lambdas,transmission_normalized)


        plt.xlabel(r'$\nu$')
        plt.ylabel('Transmission')
        plt.legend()
        plt.grid()
        plt.yscale("log")
        plt.title(foldername)
        plt.show()
# Out:
# chi_0.20_N_10000_posics
# chi_0.20_N_10000_posics Beam Spreading 0.24 - 0.44 - Sample_0 30.0ps.txt
# Configured successfully.
# 19:55:33 W. Europe Daylight Time Billed flex credit cost: 0.281.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
#                                  'run_time' should decrease the estimated, and
#                                  correspondingly the billed cost of such tasks.
# chi_0.20_N_10000_posics Beam Spreading 0.24 - 0.44 - Sample_1 30.0ps.txt
# Configured successfully.
# 19:55:35 W. Europe Daylight Time Billed flex credit cost: 0.281.
#                                  Note: the task cost pro-rated due to early
#                                  shutoff was below the minimum threshold, due to
#                                  fast shutoff. Decreasing the simulation
# ...
