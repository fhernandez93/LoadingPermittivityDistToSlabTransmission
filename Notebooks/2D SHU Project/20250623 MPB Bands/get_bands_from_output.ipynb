# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import glob
import os
from pathlib import Path

# %%
directory = "./Luis Data/bands_SHU_chi_0.37_eps_11p56_N10000"

# %%
for dirpath, dirnames, filenames in os.walk(directory):
    for filename in filenames:
        print(filename)
        if filename.endswith(".txt") or filename.endswith(".out"):
            file_path = os.path.join(dirpath, filename)
            csv_path = os.path.join(dirpath,Path(filename).stem + ".csv")
            with open(file_path, "r") as f, open(csv_path,"w") as o:
                for line in f:
                    if line.startswith("tmfreqs:, "):
                        data = line[len("tmfreqs:, "):].strip() + "\n"
                        o.write(data.replace(' ', ''))
# Out:
# 1700_freqs.txt
# 2100_bands.txt
# chi_0.37_positions.csv
# chi_0.37_positions.txt
# create_ctl_from_positions.py
# mpb_all_rods-epsilon.h5
# mpb_all_rods.ctl
