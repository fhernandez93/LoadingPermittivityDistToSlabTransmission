# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import scipy.io as sio
from dataclasses import dataclass
from typing import List, Tuple
import os
from dotenv import load_dotenv
load_dotenv()
import tidy3d as td
from tidy3d import web
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from natsort import natsorted
import numpy as np
import matplotlib.animation as animation
import xarray as xr
import imageio
import matplotlib
import sys
import os

# Assuming /AutomationModule is in the root directory of your project
sys.path.append(os.path.abspath(rf'H:\phd stuff\tidy3d'))

from AutomationModule import * 

import AutomationModule as AM

# %%
tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
a = 1
medium = td.Medium(permittivity=11.56)
run = True

# %%
folder_path=rf"H:\phd stuff\tidy3d\structures\2D SHU"
sample = 2 #number of samples to run
project_name = fr"20251010 Beam Spreading Time L=12 Abosorbers Width_0.2_2"
empty=False
runtime_ps = 25e-12
min_steps_per_lambda = 20
id0 = ""
slicing= 0.12 #Size of the structure
lambdas_range = [a/np.array([0.19,0.21]),a/np.array([0.22,0.24]),a/np.array([0.25,0.27]), a/np.array([0.27,0.29])]

# %%
for h,lamb in enumerate(lambdas_range):
 lambdas=lamb
 add_ref = False

 for l,file in enumerate(natsorted(os.listdir(folder_path))):
    if Path(file).stem not in ["chi_0.37_N_10000_posics"]:
        continue
    print(Path(file).stem)
    data = []
    centers = []

    with open(os.path.join(folder_path, file),"r") as f: 
        lines = f.read().splitlines() 
        i=0
        index = 1
        num_samples = int(lines[index].split()[0])

        while num_samples>0 and i < 300:
            try:
                num_samples = int(lines[index].split()[0])
                info = lines[index]
                old_index = index
                index += num_samples+1
                li = (lines[old_index+1:index])
                centers = np.array([list(map(float, item.split())) for item in li])
                data += [{
                    "centers":centers,
                    "Lx":float(lines[old_index].split()[1]),
                    "Ly":float(lines[old_index].split()[2]),
                    "points":float(lines[old_index].split()[0]),
                }]
                i+=1
            except:
                num_samples = 0
    

    for k,item in enumerate(data):
        #Tight pulse 

        if k >= sample:
            continue

        run_name = f"{Path(file).stem} Beam Spreading {1/lambdas[0]:.3g} - {1/lambdas[1]:.3g} - Sample_{k} {runtime_ps*1e12}ps"
        print(run_name)
        structure_1 = AM.loadAndRunStructure(key = tidy3dAPI
                    ,direction="z", lambda_range=lambdas,
                    box_size= data[k]['Lx']*a,runtime_ps=runtime_ps,min_steps_per_lambda=min_steps_per_lambda,
                   scaling=1,shuoff_condtion=1e-20, verbose=True,
                   monitors=["flux"],
                   freqs=50, 
                   source="planewave", 
                   width=0.35, ref_only=True
                   )


        sim = structure_1.sim



        boundaries= td.BoundarySpec(
                # x=td.Boundary.periodic(),
                x=td.Boundary(plus=td.Absorber(num_layers=250),minus=td.Absorber(num_layers=250)),
                y=td.Boundary(plus=td.Absorber(num_layers=250),minus=td.Absorber(num_layers=250)),
                z=td.Boundary.periodic(),
            )
        sim = sim.copy(update={'boundary_spec':boundaries})
        sim = sim.copy(update={'sources':[]})
        sim = sim.copy(update={'monitors':[]})


        Lx, Ly = data[k]['Lx'],data[k]['Ly']*slicing+40
        sim = sim.copy(update={'size':[Lx,Ly,0]})

        lambda0 = np.sum(lambdas)/2
        source = td.PlaneWave(
                source_time = td.GaussianPulse(
                    freq0=td.C_0/lambda0,
                    fwidth=(td.C_0/lambdas[1] - td.C_0/lambdas[0])*0.4,
                    offset=10
                ),
                size= (2.5,0,td.inf),
                center=(0,-(Lx)*slicing/2 - 3,0),
                direction='+',
                pol_angle=np.pi/2,
                name='planewave',
                )

        

        sim = sim.copy(update={'sources':[source]})

        time_monitorFieldOut = td.FieldTimeMonitor(
                    center = (0,0,0),
                    size = (Lx,Ly,0),
                        start=0,
                        stop=structure_1.t_stop,
                        interval=50,
                        fields=["Ex", "Ey", "Ez"],
                        name="time_monitorFieldOut",

                    )


        time_monitorT = td.FluxTimeMonitor(
                        center = (
                                0,(Lx*slicing)/2,0
                                ),
                    size = (
                       td.inf,0,td.inf
                        ),
                        start=0,
                        stop=structure_1.t_stop,
                        interval = 250,
                        name="time_monitorT",

                    )
        

        sim = sim.copy(update={'monitors':[time_monitorFieldOut,time_monitorT]})

        cyl_group = []
        for x,y in data[k]['centers']:
            if np.abs(y)<=(Lx/2)*slicing:
                cyl_group.append(td.Cylinder(center=[x, y, 0], radius=0.189, length=td.inf))

        cylinders = td.Structure(geometry=td.GeometryGroup(geometries=cyl_group), medium=medium)

       
        sim = sim.copy(update={'structures':[cylinders],"grid_spec": td.GridSpec.uniform(dl=structure_1.dl)})

        fig, ax = plt.subplots(1, tight_layout=True, figsize=(16, 8))
        sim.plot(z=0, ax=ax)
        plt.show()

        sim_name = run_name
        if run:
            incidence_folder = Path(file).stem + rf"/nu_{a/lambdas[0]:.2f}-{a/lambdas[1]:.2f}"
            file_path = rf"H:\phd stuff\tidy3d\data/{project_name}/{incidence_folder}/{sim_name}.txt"
            # Check if the folder exists
            if not os.path.exists( fr"H:\phd stuff\tidy3d\data/{project_name}/{incidence_folder}"):
                os.makedirs(fr"H:\phd stuff\tidy3d\data/{project_name}/{incidence_folder}")
                print(fr"Folder 'H:\phd stuff\tidy3d\data/{project_name}/{incidence_folder}' created successfully.")

            if os.path.exists(file_path):
                print("Exist!!")

            else:
                if add_ref:
                     id0 =web.upload(sim.copy(update={'structures':[]}), folder_name=project_name,task_name=fr"{sim_name}_0", verbose=True)
                     web.start(task_id = id0)
                     web.monitor(task_id=id0,verbose=True)
                     add_ref = False

                id =web.upload(sim, folder_name=project_name,task_name=sim_name, verbose=True)
                web.start(task_id = id)
                web.monitor(task_id=id,verbose=True)
                ids = id0+ '\n' + id

                # Open file in write mode
                with open(file_path, "w") as f:
                    # Write the string to the file
                    f.write(ids)
        else:
            # sim.plot_3d()
            raise TypeError("Program ends here")
# Out:
# chi_0.37_N_10000_posics
# chi_0.37_N_10000_posics Beam Spreading 0.19 - 0.21 - Sample_0 25.0ps
# Configured successfully.
# Folder 'H:\phd stuff\tidy3d\data/20251010 Beam Spreading Time L=12 Abosorbers Width_0.2_1/chi_0.37_N_10000_posics/nu_0.19-0.21' created successfully.
# 15:07:42 W. Europe Daylight Time Created task 'chi_0.37_N_10000_posics Beam
#                                  Spreading 0.19 - 0.21 - Sample_0 25.0ps' with
#                                  task_id
#                                  'fdve-f737afd2-aef6-43ac-a1a2-343b838af714' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=723928;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=784133;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\task]8;;\
#                                  ]8;id=784133;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\Id]8;;\]8;id=723928;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\=]8;;\]8;id=239619;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\fdve]8;;\]8;id=723928;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\-f737afd2-aef6-43ac-a1a2-343b838af714']8;;\.
#                                  Task folder: ]8;id=215634;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\'20251010 Beam Spreading Time ]8;;\]8;id=224344;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\L]8;;\]8;id=215634;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\=]8;;\]8;id=377312;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\12]8;;\
#                                  ]8;id=215634;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\Abosorbers Width_0.2_1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:07:45 W. Europe Daylight Time Maximum FlexCredit cost: 0.025. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 15:07:47 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:07:59 W. Europe Daylight Time You are running this simulation for FREE. Your
#                                  current plan allows up to 20 free
#                                  non-concurrent simulations per day (under
#                                  100.0M grid points and 50.0K time steps)
#                                  starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# 15:08:13 W. Europe Daylight Time status = postprocess
# 15:08:28 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:08:30 W. Europe Daylight Time View simulation result at
#                                  ]8;id=459522;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=318838;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\task]8;;\
#                                  ]8;id=318838;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\Id]8;;\]8;id=459522;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\=]8;;\]8;id=978142;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\fdve]8;;\]8;id=459522;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f737afd2-aef6-43ac-a1a2-343b838af714\-f737afd2-aef6-43ac-a1a2-343b838af714']8;;\.
# chi_0.37_N_10000_posics Beam Spreading 0.19 - 0.21 - Sample_1 25.0ps
# Configured successfully.
# 15:08:32 W. Europe Daylight Time Created task 'chi_0.37_N_10000_posics Beam
#                                  Spreading 0.19 - 0.21 - Sample_1 25.0ps' with
#                                  task_id
#                                  'fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=149111;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=785477;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\task]8;;\
#                                  ]8;id=785477;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\Id]8;;\]8;id=149111;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\=]8;;\]8;id=588791;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\fdve]8;;\]8;id=149111;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\-b9814f37-4b34-40fa-ac28-c48759b2ec36']8;;\.
#                                  Task folder: ]8;id=152999;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\'20251010 Beam Spreading Time ]8;;\]8;id=535151;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\L]8;;\]8;id=152999;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\=]8;;\]8;id=350164;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\12]8;;\
#                                  ]8;id=152999;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\Abosorbers Width_0.2_1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:08:35 W. Europe Daylight Time Maximum FlexCredit cost: 0.025. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 15:08:37 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:08:46 W. Europe Daylight Time You are running this simulation for FREE. Your
#                                  current plan allows up to 20 free
#                                  non-concurrent simulations per day (under
#                                  100.0M grid points and 50.0K time steps)
#                                  starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# 15:08:57 W. Europe Daylight Time status = postprocess
# 15:09:11 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:09:13 W. Europe Daylight Time View simulation result at
#                                  ]8;id=573586;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=181608;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\task]8;;\
#                                  ]8;id=181608;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\Id]8;;\]8;id=573586;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\=]8;;\]8;id=926547;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\fdve]8;;\]8;id=573586;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b9814f37-4b34-40fa-ac28-c48759b2ec36\-b9814f37-4b34-40fa-ac28-c48759b2ec36']8;;\.
# chi_0.37_N_10000_posics
# chi_0.37_N_10000_posics Beam Spreading 0.22 - 0.24 - Sample_0 25.0ps
# Configured successfully.
# Folder 'H:\phd stuff\tidy3d\data/20251010 Beam Spreading Time L=12 Abosorbers Width_0.2_1/chi_0.37_N_10000_posics/nu_0.22-0.24' created successfully.
# 15:09:16 W. Europe Daylight Time Created task 'chi_0.37_N_10000_posics Beam
#                                  Spreading 0.22 - 0.24 - Sample_0 25.0ps' with
#                                  task_id
#                                  'fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=919008;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=900744;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\task]8;;\
#                                  ]8;id=900744;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\Id]8;;\]8;id=919008;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\=]8;;\]8;id=21921;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\fdve]8;;\]8;id=919008;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\-b02dc1be-9af9-491a-8432-8d6ba17eaee1']8;;\.
#                                  Task folder: ]8;id=963157;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\'20251010 Beam Spreading Time ]8;;\]8;id=731098;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\L]8;;\]8;id=963157;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\=]8;;\]8;id=45194;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\12]8;;\
#                                  ]8;id=963157;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\Abosorbers Width_0.2_1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:09:19 W. Europe Daylight Time Maximum FlexCredit cost: 0.025. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 15:09:20 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:09:32 W. Europe Daylight Time starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:09:48 W. Europe Daylight Time status = postprocess
# Output()
# 15:10:10 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:10:12 W. Europe Daylight Time View simulation result at
#                                  ]8;id=949556;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=929816;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\task]8;;\
#                                  ]8;id=929816;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\Id]8;;\]8;id=949556;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\=]8;;\]8;id=17895;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\fdve]8;;\]8;id=949556;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b02dc1be-9af9-491a-8432-8d6ba17eaee1\-b02dc1be-9af9-491a-8432-8d6ba17eaee1']8;;\.
# chi_0.37_N_10000_posics Beam Spreading 0.22 - 0.24 - Sample_1 25.0ps
# Configured successfully.
# 15:10:14 W. Europe Daylight Time Created task 'chi_0.37_N_10000_posics Beam
#                                  Spreading 0.22 - 0.24 - Sample_1 25.0ps' with
#                                  task_id
#                                  'fdve-c60af877-cada-410a-bca7-3c88a0668051' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=759817;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=401942;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\task]8;;\
#                                  ]8;id=401942;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\Id]8;;\]8;id=759817;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\=]8;;\]8;id=886442;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\fdve]8;;\]8;id=759817;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\-c60af877-cada-410a-bca7-3c88a0668051']8;;\.
#                                  Task folder: ]8;id=572618;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\'20251010 Beam Spreading Time ]8;;\]8;id=350;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\L]8;;\]8;id=572618;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\=]8;;\]8;id=286179;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\12]8;;\
#                                  ]8;id=572618;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\Abosorbers Width_0.2_1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:10:17 W. Europe Daylight Time Maximum FlexCredit cost: 0.025. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 15:10:19 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# 15:10:24 W. Europe Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:10:28 W. Europe Daylight Time starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:10:46 W. Europe Daylight Time status = postprocess
# Output()
# 15:11:06 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:11:08 W. Europe Daylight Time View simulation result at
#                                  ]8;id=712252;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=242965;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\task]8;;\
#                                  ]8;id=242965;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\Id]8;;\]8;id=712252;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\=]8;;\]8;id=301921;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\fdve]8;;\]8;id=712252;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c60af877-cada-410a-bca7-3c88a0668051\-c60af877-cada-410a-bca7-3c88a0668051']8;;\.
# chi_0.37_N_10000_posics
# chi_0.37_N_10000_posics Beam Spreading 0.25 - 0.27 - Sample_0 25.0ps
# Configured successfully.
# Folder 'H:\phd stuff\tidy3d\data/20251010 Beam Spreading Time L=12 Abosorbers Width_0.2_1/chi_0.37_N_10000_posics/nu_0.25-0.27' created successfully.
# 15:11:12 W. Europe Daylight Time Created task 'chi_0.37_N_10000_posics Beam
#                                  Spreading 0.25 - 0.27 - Sample_0 25.0ps' with
#                                  task_id
#                                  'fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=468274;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=82099;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\task]8;;\
#                                  ]8;id=82099;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\Id]8;;\]8;id=468274;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\=]8;;\]8;id=204517;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\fdve]8;;\]8;id=468274;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc']8;;\.
#                                  Task folder: ]8;id=92023;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\'20251010 Beam Spreading Time ]8;;\]8;id=663557;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\L]8;;\]8;id=92023;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\=]8;;\]8;id=868816;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\12]8;;\
#                                  ]8;id=92023;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\Abosorbers Width_0.2_1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:11:15 W. Europe Daylight Time Maximum FlexCredit cost: 0.025. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 15:11:17 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# 15:11:22 W. Europe Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:11:27 W. Europe Daylight Time starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# 15:11:51 W. Europe Daylight Time status = postprocess
# 15:12:25 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:12:27 W. Europe Daylight Time View simulation result at
#                                  ]8;id=665393;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=861591;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\task]8;;\
#                                  ]8;id=861591;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\Id]8;;\]8;id=665393;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\=]8;;\]8;id=158095;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\fdve]8;;\]8;id=665393;https://tidy3d.simulation.cloud/workbench?taskId=fdve-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc\-acf8a82c-a8d5-4de3-a42f-a0f0c5fe2fcc']8;;\.
# chi_0.37_N_10000_posics Beam Spreading 0.25 - 0.27 - Sample_1 25.0ps
# Configured successfully.
# 15:12:28 W. Europe Daylight Time Created task 'chi_0.37_N_10000_posics Beam
#                                  Spreading 0.25 - 0.27 - Sample_1 25.0ps' with
#                                  task_id
#                                  'fdve-916e5f1b-4a35-4444-955e-341533bc6dc5' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=613574;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=524155;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\task]8;;\
#                                  ]8;id=524155;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\Id]8;;\]8;id=613574;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\=]8;;\]8;id=156864;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\fdve]8;;\]8;id=613574;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\-916e5f1b-4a35-4444-955e-341533bc6dc5']8;;\.
#                                  Task folder: ]8;id=293589;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\'20251010 Beam Spreading Time ]8;;\]8;id=414779;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\L]8;;\]8;id=293589;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\=]8;;\]8;id=11837;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\12]8;;\
#                                  ]8;id=293589;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\Abosorbers Width_0.2_1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:12:31 W. Europe Daylight Time Maximum FlexCredit cost: 0.025. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 15:12:33 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:12:42 W. Europe Daylight Time starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# 15:13:06 W. Europe Daylight Time status = postprocess
# 15:13:37 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:13:39 W. Europe Daylight Time View simulation result at
#                                  ]8;id=355414;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=964357;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\task]8;;\
#                                  ]8;id=964357;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\Id]8;;\]8;id=355414;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\=]8;;\]8;id=593043;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\fdve]8;;\]8;id=355414;https://tidy3d.simulation.cloud/workbench?taskId=fdve-916e5f1b-4a35-4444-955e-341533bc6dc5\-916e5f1b-4a35-4444-955e-341533bc6dc5']8;;\.
# chi_0.37_N_10000_posics
# chi_0.37_N_10000_posics Beam Spreading 0.27 - 0.29 - Sample_0 25.0ps
# Configured successfully.
# Folder 'H:\phd stuff\tidy3d\data/20251010 Beam Spreading Time L=12 Abosorbers Width_0.2_1/chi_0.37_N_10000_posics/nu_0.27-0.29' created successfully.
# 15:13:42 W. Europe Daylight Time Created task 'chi_0.37_N_10000_posics Beam
#                                  Spreading 0.27 - 0.29 - Sample_0 25.0ps' with
#                                  task_id
#                                  'fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=994645;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=497218;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\task]8;;\
#                                  ]8;id=497218;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\Id]8;;\]8;id=994645;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\=]8;;\]8;id=345431;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\fdve]8;;\]8;id=994645;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\-c1b8257f-92e7-4f78-8931-0948bc3dfc9f']8;;\.
#                                  Task folder: ]8;id=85660;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\'20251010 Beam Spreading Time ]8;;\]8;id=521630;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\L]8;;\]8;id=85660;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\=]8;;\]8;id=242111;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\12]8;;\
#                                  ]8;id=85660;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\Abosorbers Width_0.2_1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:13:45 W. Europe Daylight Time Maximum FlexCredit cost: 0.025. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 15:13:46 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:13:53 W. Europe Daylight Time starting up solver
#                                  running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# 15:14:17 W. Europe Daylight Time status = postprocess
# 15:14:50 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:14:52 W. Europe Daylight Time View simulation result at
#                                  ]8;id=35266;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=698613;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\task]8;;\
#                                  ]8;id=698613;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\Id]8;;\]8;id=35266;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\=]8;;\]8;id=261650;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\fdve]8;;\]8;id=35266;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c1b8257f-92e7-4f78-8931-0948bc3dfc9f\-c1b8257f-92e7-4f78-8931-0948bc3dfc9f']8;;\.
# chi_0.37_N_10000_posics Beam Spreading 0.27 - 0.29 - Sample_1 25.0ps
# Configured successfully.
# 15:14:55 W. Europe Daylight Time Created task 'chi_0.37_N_10000_posics Beam
#                                  Spreading 0.27 - 0.29 - Sample_1 25.0ps' with
#                                  task_id
#                                  'fdve-12d531aa-6559-4739-876c-202de120847f' and
#                                  task_type 'FDTD'.
#                                  View task using web UI at
#                                  ]8;id=620241;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=610299;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\task]8;;\
#                                  ]8;id=610299;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\Id]8;;\]8;id=620241;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\=]8;;\]8;id=94594;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\fdve]8;;\]8;id=620241;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\-12d531aa-6559-4739-876c-202de120847f']8;;\.
#                                  Task folder: ]8;id=610340;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\'20251010 Beam Spreading Time ]8;;\]8;id=153781;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\L]8;;\]8;id=610340;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\=]8;;\]8;id=957566;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\12]8;;\
#                                  ]8;id=610340;https://tidy3d.simulation.cloud/folders/folder-7b6581f7-8eeb-40eb-81d7-beb692bc5c65\Abosorbers Width_0.2_1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 15:14:58 W. Europe Daylight Time Maximum FlexCredit cost: 0.025. Minimum cost
#                                  depends on task execution details. Use
#                                  'web.real_cost(task_id)' to get the billed
#                                  FlexCredit cost after a simulation run.
# 15:14:59 W. Europe Daylight Time status = queued
#                                  To cancel the simulation, use
#                                  'web.abort(task_id)' or 'web.delete(task_id)'
#                                  or abort/delete the task in the web UI.
#                                  Terminating the Python script will not stop the
#                                  job running on the cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:15:08 W. Europe Daylight Time starting up solver
# 15:15:09 W. Europe Daylight Time running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# 15:15:44 W. Europe Daylight Time status = postprocess
# 15:16:25 W. Europe Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:16:27 W. Europe Daylight Time View simulation result at
#                                  ]8;id=162798;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=386936;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\task]8;;\
#                                  ]8;id=386936;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\Id]8;;\]8;id=162798;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\=]8;;\]8;id=179808;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\fdve]8;;\]8;id=162798;https://tidy3d.simulation.cloud/workbench?taskId=fdve-12d531aa-6559-4739-876c-202de120847f\-12d531aa-6559-4739-876c-202de120847f']8;;\.
